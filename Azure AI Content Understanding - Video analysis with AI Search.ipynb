# %% [markdown]
# # Azure AI Content Understanding
# ## Video Search with Azure Content Understanding and Azure AI Search
#
# <img src="https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/media/overview/component-overview.png">
#
# ## Objective
# This document is meant to present a guideline on how to leverage the Azure Video Content Understanding API for AI Search.
# The sample will demonstrate the following steps:
# 1. Process a video file from Azure Blob storage with the Azure Video Content Understanding service to generate a video description grounding document.
# 2. Process the video description grounding document with Azure Search client to generate an Azure Search index.
# 3. Utilize OpenAI completion and embedding models to search through content in the video search index.
#
# ## Settings
# 1.	Azure AI services: Go to Access Control (IAM) in resource, grant yourself role **Cognitive Services User**
# 3.	Azure OpenAI: Go to Access Control (IAM) in resource, grant yourself role **Cognitive Services OpenAI User**
# 7.	Azure AI Search: Go to Access Control (IAM) in resource, grant yourself role **Search Index Data Contributor**. Go to Access Control (IAM) in resource, grant yourself role **Search Service Contributor**.
#
# https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/overview

# %%
import cv2
import datetime
import json
import matplotlib.pyplot as plt
import os
import requests
import sys
import time

from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from azure_content_understanding import AzureContentUnderstandingClient
from dotenv import load_dotenv
from IPython.display import Video
from langchain.schema import Document, StrOutputParser
from langchain.schema.runnable import RunnablePassthrough
from langchain.vectorstores.azuresearch import AzureSearch
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import AzureChatOpenAI, AzureOpenAIEmbeddings
from moviepy import *

# %%
sys.version
# Out:
# '3.10.14 (main, May  6 2024, 19:42:50) [GCC 11.2.0]'

# %%
print(f"Today is: {datetime.datetime.today().strftime('%d-%b-%Y %H:%M:%S')}")
# Out:
# Today is: 31-Jan-2025 12:49:36

# %%
JSON_DIR = "json"
DOCUMENTS_DIR = "documents"

# %% [markdown]
# ## Load environment variables

# %%
load_dotenv("azure.env")

AZURE_AI_SERVICE_ENDPOINT = os.getenv("AZURE_AI_ENDPOINT")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")

AZURE_SEARCH_ENDPOINT = os.getenv("AZURE_SEARCH_ENDPOINT")
AZURE_SEARCH_KEY = os.getenv("AZURE_SEARCH_KEY")

# %%
AZURE_OPENAI_CHAT_DEPLOYMENT_NAME = "gpt-4o"
AZURE_OPENAI_CHAT_API_VERSION = "2025-01-01-preview"

AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME = "text-embedding-ada-002"
AZURE_OPENAI_EMBEDDING_API_VERSION = "2025-01-01-preview"
AZURE_AI_SERVICE_API_VERSION = "2024-12-01-preview"

AZURE_SEARCH_INDEX_NAME = "azure_cu_movieteaser"

# %% [markdown]
# ## Helper

# %%
def convert_values_to_strings(json_obj):
    """
    Convert all values in a JSON object to strings.

    Args:
        json_obj (dict): A dictionary representing the JSON object.

    Returns:
        list: A list of string representations of the values in the JSON object.
    """

    return [str(value) for value in json_obj]

# %%
def remove_markdown(json_obj):
    """
    Remove 'markdown' keys from all segments in a JSON object.

    Args:
        json_obj (list): A list of dictionaries representing the JSON object.

    Returns:
        list: The modified JSON object with 'markdown' keys removed from each segment.
    """
    for segment in json_obj:
        if 'markdown' in segment:
            del segment['markdown']

    return json_obj

# %%
def get_scene_description(scene_description):
    """
    Process a scene description to generate a list of Document objects.

    This function extracts audio-visual segments from the provided scene description,
    removes any 'markdown' keys, converts the segment values to strings, and formats
    them into JSON strings. Each formatted string is then wrapped in a Document object.

    Args:
        scene_description (dict): A dictionary containing the scene description with
                                  audio-visual segments.

    Returns:
        list: A list of Document objects, each containing a formatted JSON string
              representing a video segment with scene description and transcript.
    """
    audio_visual_segments = scene_description["result"]["contents"]

    filtered_audio_visual_segments = remove_markdown(audio_visual_segments)

    audio_visual_splits = [
        "The following is a json string representing a video segment with scene description and transcript ```"
        + v + "```"
        for v in convert_values_to_strings(filtered_audio_visual_segments)
    ]

    docs = [Document(page_content=v) for v in audio_visual_splits]

    return docs

# %%
def load_into_index(docs):
    """
    Embed and index a list of documents using Azure OpenAI and Azure Search.

    This function creates embeddings for the provided documents using Azure OpenAI,
    and then indexes these documents in an Azure Search service.

    Args:
        docs (list): A list of Document objects to be embedded and indexed.

    Returns:
        AzureSearch: An AzureSearch object containing the indexed documents.
    """
    # Azure OpenAI Embeddings
    aoai_embeddings = AzureOpenAIEmbeddings(
        azure_deployment=AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME,
        openai_api_version=AZURE_OPENAI_EMBEDDING_API_VERSION,
        azure_endpoint=AZURE_OPENAI_ENDPOINT,
        azure_ad_token_provider=token_provider)

    # Loading to the vector store
    vector_store: AzureSearch = AzureSearch(
        azure_search_endpoint=AZURE_SEARCH_ENDPOINT,
        azure_search_key=AZURE_SEARCH_KEY,
        index_name=AZURE_SEARCH_INDEX_NAME,
        embedding_function=aoai_embeddings.embed_query)
    vector_store.add_documents(documents=docs)

    return vector_store

# %%
def get_index_stats(index_name):
    """
    Retrieves and displays the statistics of an Azure AI Search index.

    Parameters:
    index_name (str): The name of the Azure AI Search index.

    Returns:
    tuple: A tuple containing the following:
        - document_count (int): The number of documents in the index.
        - storage_size (int): The storage size of the index in bytes.

    This function sends a GET request to the Azure Cognitive Search service to retrieve the statistics
    of the specified index. It prints the status and statistics of the index, including the document count
    and storage size. If the request fails, it prints the status code of the failed request.
    """
    url = AZURE_SEARCH_ENDPOINT + "/indexes/" + index_name + "/stats?api-version=2021-04-30-Preview"
    headers = {
        "Content-Type": "application/json",
        "api-key": AZURE_SEARCH_KEY,
    }
    response = requests.get(url, headers=headers)
    print("Azure Cognitive Search index status for:", index_name, "\n")

    if response.status_code == 200:
        res = response.json()
        print(json.dumps(res, indent=2))
        document_count = res['documentCount']
        storage_size = res['storageSize']

    else:
        print("Request failed with status code:", response.status_code)

    return document_count, storage_size

# %%
def index_status(index_name):
    """
    Retrieves and displays the status of an Azure AI Search index.

    Parameters:
    index_name (str): The name of the Azure AI Search index.

    Returns:
    None: This function prints the status of the specified index in a formatted JSON structure.
          If the request fails, it prints an error message.

    This function sends a GET request to the Azure AI Search service to retrieve the status
    of the specified index. It prints the index name and the status information in a formatted
    JSON structure. If the request fails, it catches the exception and prints a failure message.
    """
    print("Azure AI Search Index:", index_name, "\n")

    headers = {"Content-Type": "application/json", "api-key": AZURE_SEARCH_KEY}
    params = {"api-version": "2021-04-30-Preview"}
    index_status = requests.get(AZURE_SEARCH_ENDPOINT + "/indexes/" +
                                index_name,
                                headers=headers,
                                params=params)
    try:
        print(json.dumps((index_status.json()), indent=5))
    except:
        print("Request failed")

# %%
def get_fields_result(res_string):
    """
    Extracts various fields from a string.

    Parameters:
    res_string (str): A string.

    Returns:
    tuple: A tuple containing the following extracted fields:
        - scene_desc (str): The scene description.
        - kind (str): The kind of the segment.
        - startTimeMs (int): The start time in milliseconds.
        - endTimeMs (int): The end time in milliseconds.
        - width (int): The width of the segment.
        - height (int): The height of the segment.
        - keyFrameTimesMs (list of int): A list of key frame times in milliseconds.
        - transcriptPhrases (list of str): A list of transcript phrases.
    """
    # Extract scene desc
    start_value_string = res_string.find('"valueString": "') + len(
        '"valueString": "')
    end_value_string = res_string.find('"}', start_value_string)
    scene_desc = res_string[start_value_string:end_value_string]

    # Extract kind
    start_kind = res_string.find('"kind": "') + len('"kind": "')
    end_kind = res_string.find('"', start_kind)
    kind = res_string[start_kind:end_kind]

    # Extract startTimeMs
    start_startTimeMs = res_string.find('"startTimeMs": ') + len(
        '"startTimeMs": ')
    end_startTimeMs = res_string.find(',', start_startTimeMs)
    startTimeMs = int(res_string[start_startTimeMs:end_startTimeMs])

    # Extract endTimeMs
    start_endTimeMs = res_string.find('"endTimeMs": ') + len('"endTimeMs": ')
    end_endTimeMs = res_string.find(',', start_endTimeMs)
    endTimeMs = int(res_string[start_endTimeMs:end_endTimeMs])

    # Extract width
    start_width = res_string.find('"width": ') + len('"width": ')
    end_width = res_string.find(',', start_width)
    width = int(res_string[start_width:end_width])

    # Extract height
    start_height = res_string.find('"height": ') + len('"height": ')
    end_height = res_string.find(',', start_height)
    height = int(res_string[start_height:end_height])

    # Extract KeyFrameTimesMs
    start_keyFrameTimesMs = res_string.find('"KeyFrameTimesMs": [') + len(
        '"KeyFrameTimesMs": [')
    end_keyFrameTimesMs = res_string.find(']', start_keyFrameTimesMs)
    keyFrameTimesMs_str = res_string[start_keyFrameTimesMs:end_keyFrameTimesMs]
    keyFrameTimesMs = [int(x) for x in keyFrameTimesMs_str.split(',')]

    # Extract transcriptPhrases
    start_transcriptPhrases = res_string.find('"transcriptPhrases": [') + len(
        '"transcriptPhrases": [')
    end_transcriptPhrases = res_string.find(']', start_transcriptPhrases)
    transcriptPhrases_str = res_string[
        start_transcriptPhrases:end_transcriptPhrases]
    transcriptPhrases = [
        x.strip() for x in transcriptPhrases_str.split(',') if x.strip()
    ]

    return scene_desc, kind, startTimeMs, endTimeMs, width, height, keyFrameTimesMs, transcriptPhrases

# %%
def display_results(docs):
    """
    Displays the extracted fields from a list of document objects.

    Parameters:
    docs (list): A list of document objects, each containing a page_content attribute with JSON-like data.

    Returns:
    None: This function prints the extracted fields for each document.
    """
    for i, doc in enumerate(docs, start=1):
        print("\033[1;31;34m")
        res_string = doc.page_content.split("```")[1].replace("'", "\"")

        print(f"Results {i}:\n")
        scene_desc, kind, startTimeMs, endTimeMs, width, height, keyFrameTimesMs, transcriptPhrases = get_fields_result(
            res_string)

        print("Scene description:", scene_desc)
        print("Kind:", kind)
        print("StartTimeMs:", startTimeMs)
        print("EndTimeMs:", endTimeMs)
        print("Width:", width)
        print("Height:", height)
        print("KeyFrameTimesMs:", keyFrameTimesMs)
        print("TranscriptPhrases:", transcriptPhrases)

# %%
def conversational_search(rag_chain, query):
    """
    Perform a conversational search using a Retrieval-Augmented Generation (RAG) chain.

    This function takes a query, invokes the RAG chain with the query, and prints the result.

    Args:
        rag_chain (dict): A dictionary representing the RAG chain, which includes the context retriever,
                          prompt, language model, and output parser.
        query (str): The search query to be processed by the RAG chain.

    Returns:
        None
    """
    print(rag_chain.invoke(query))

# %%
def generate_subclip(video_file, start_time_ms, end_time_ms):
    """
    Generates a subclip from a video file.

    This function takes a video file and extracts a subclip from it, starting
    slightly before the specified start time and ending slightly after the
    specified end time. The subclip is then saved as "sample.mp4".

    Parameters
    ----------
    video_file : str
        The path to the video file.
    start_time_ms : int
        The start time of the subclip in milliseconds.
    end_time_ms : int
        The end time of the subclip in milliseconds.

    Returns
    -------
    None
    """
    start = int(start_time_ms / 1000) - 1
    end =  int(end_time_ms / 1000) + 1
    clip = VideoFileClip(video_file).subclipped(start, end)
    clip.write_videofile("sample.mp4", codec="libx264")

# %% [markdown]
# ## File to Analyze

# %%
video_file = os.path.join(DOCUMENTS_DIR, "movie.mp4")

# %%
Video(video_file, width=512)
# Out:
# <video src="documents/movie.mp4" controls  width="512" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
vid = cv2.VideoCapture(video_file)

fps = int(vid.get(cv2.CAP_PROP_FPS))
nbframes = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
duration = nbframes / fps
min_vid = int(duration // 60)
sec_vid = int(duration % 60)

print(f"Duration of {video_file} = {min_vid} minutes and {sec_vid} seconds")
print(f"Total number of frames = {nbframes}")
print(f"FPS = {fps}")
# !ls $video_file -lh
# Out:
# Duration of documents/movie.mp4 = 2 minutes and 31 seconds
# Total number of frames = 3474
# FPS = 23
# -rwxrwxrwx 1 root root 17M Jan 31 08:37 documents/movie.mp4

# %% [markdown]
# ## Generate Video Segment Description
# Create a custom analyzer with pre-defined schema. The custom analyzer schema is defined in [./video_content_understanding_basic.json](./video_content_understanding_basic.json)

# %%
ANALYZER_TEMPLATE_PATH = os.path.join(JSON_DIR, "video_content_understanding.json")

ANALYZER_ID = f"videoanalyzer{datetime.datetime.today().strftime('%d%b%Y%H%M%S')}"

# %%
credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(
    credential, "https://cognitiveservices.azure.com/.default")

# Create the Azure Content Understanding client
client = AzureContentUnderstandingClient(
    endpoint=AZURE_AI_SERVICE_ENDPOINT,
    api_version=AZURE_AI_SERVICE_API_VERSION,
    token_provider=token_provider,
    x_ms_useragent=
    "azure-ai-content-understanding-python/search_with_video",  # This header is used for sample usage telemetry
)

# %%
response = client.begin_create_analyzer(ANALYZER_ID, analyzer_template_path=ANALYZER_TEMPLATE_PATH)
result = client.poll_result(response)

print("\033[1;31;35m")
print(json.dumps(result, indent=4))
# Out:
# {
#     "id": "622f01b0-3804-4299-9973-4baf2b8d6e28",
#     "status": "Succeeded",
#     "result": {
#         "analyzerId": "videoanalyzer31Jan2025124942",
#         "description": "Generating content understanding from video.",
#         "createdAt": "2025-01-31T12:49:43Z",
#         "lastModifiedAt": "2025-01-31T12:49:43Z",
#         "config": {
#             "locales": [
#                 "en-US",
#                 "es-ES",
#                 "es-MX",
#                 "fr-FR",
#                 "hi-IN",
#                 "it-IT",
#                 "ja-JP",
#                 "ko-KR",
#                 "pt-BR",
#                 "zh-CN"
#             ],
#             "returnDetails": true,
#             "enableFace": false
#         },
#         "fieldSchema": {
#             "name": "Content Understanding",
#             "fields": {
#                 "segmentDescription": {
#                     "type": "string",
#                     "description": "Detailed summary of the video segment, focusing on people, places, and actions taking place."
#                 }
#             }
#         },
#         "warnings": [],
#         "status": "ready",
#         "scenario": "videoShot"
#     }
# }

# %% [markdown]
# ### Use the created analyzer to extract video segment description

# %%
start = time.time()

# Submit the video for content analysis
response = client.begin_analyze(ANALYZER_ID, file_location=video_file)

# Wait for the analysis to complete and get the content analysis result
video_result = client.poll_result(response, timeout_seconds=3600)

elapsed = time.time() - start
print(f"Done in {time.strftime('%H:%M:%S.' + str(elapsed % 1)[2:5], time.gmtime(elapsed))}")
# Out:
# Done in 00:02:31.631

# %%
print(json.dumps(video_result, indent=4))
# Out:
# {
#     "id": "80f9e90a-fcd9-4be5-9e2c-42875662c16a",
#     "status": "Succeeded",
#     "result": {
#         "analyzerId": "videoanalyzer31Jan2025124942",
#         "apiVersion": "2024-12-01-preview",
#         "createdAt": "2025-01-31T12:49:45Z",
#         "warnings": [
#             {
#                 "code": "HarmfulContentDetected",
#                 "message": "Content of category 'Violence' detected with severity 'Low'. Please use the field content with caution."
#             },
#             {
#                 "code": "HarmfulContentDetected",
#                 "message": "Content of category 'Violence' detected with severity 'Low'. Please use the field content with caution."
#             },
#             {
#                 "code": "HarmfulContentDetected",
#                 "message": "Content of category 'Violence' detected with severity 'Low'. Please use the field content with caution."
#             },
#             {
#                 "code": "HarmfulContentDetected",
#                 "message": "Content of category 'Violence' detected with severity 'Low'. Please use the field content with caution."
#             },
#             {
#                 "code": "HarmfulContentDetected",
#                 "message": "Content of category 'Violence' detected with severity 'Low'. Please use the field content with caution."
#             },
#             {
#                 "code": "HarmfulContentDetected",
#                 "message": "Content of category 'Sexual' detected with severity 'Low'. Please use the field content with caution."
#             },
#             {
#                 "code": "HarmfulContentDetected",
#                 "message": "Content of category 'Violence' detected with severity 'Low'. Please use the field content with caution."
#             },
#             {
#                 "code": "HarmfulContentDetected",
#                 "message": "Content of category 'Violence' detected with severity 'Low'. Please use the field content with caution."
#             },
#             {
#                 "code": "HarmfulContentDetected",
#                 "message": "Content of category 'Violence' detected with severity 'Low'. Please use the field content with caution."
#             },
#             {
#                 "code": "HarmfulContentDetected",
#                 "message": "Content of category 'Violence' detected with severity 'Low'. Please use the field content with caution."
#             },
#             {
#                 "code": "HarmfulContentDetected",
#                 "message": "Content of category 'Violence' detected with severity 'Low'. Please use the field content with caution."
#             }
#         ],
#         "contents": [
#             {
#                 "markdown": "# Shot 00:00.000 => 00:01.418\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 00:00.737 ![](keyFrame.737.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The video opens with the iconic Warner Bros. Pictures logo, signaling the beginning of a movie. The logo is presented in its typical format, showing the emblem with the text \"A TimeWarner Company\" beneath it."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 0,
#                 "endTimeMs": 1418,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     737
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 00:01.418 => 00:03.253\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 00:02.048 ![](keyFrame.2048.jpg)\n- 00:02.662 ![](keyFrame.2662.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The Warner Bros. Pictures logo fades out, and the screen transitions to black, maintaining a sense of anticipation for what is to follow."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 1418,
#                 "endTimeMs": 3253,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     2048,
#                     2662
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 00:03.253 => 00:04.963\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 00:03.809 ![](keyFrame.3809.jpg)\n- 00:04.382 ![](keyFrame.4382.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A scene is shown depicting a quiet urban street corner. A white pickup truck drives past a stop sign, and a group of individuals can be seen standing near a brick building. The street is lined with houses and appears to be a typical suburban area."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 3253,
#                 "endTimeMs": 4963,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     3809,
#                     4382
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 00:04.963 => 00:06.298\n## Transcript\n```\nWEBVTT\n\n00:05.440 --> 00:05.960\n<v Speaker>Come here, girl.\n00:05.960 --> 00:06.120\n<v Speaker>Stop.\n```\n## Key Frames\n- 00:05.652 ![](keyFrame.5652.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A tense moment is captured as a young woman is being grabbed by the arm by a man, indicating a possible confrontation or struggle. Several other individuals are present in the scene, observing the interaction."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 4963,
#                 "endTimeMs": 6298,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     5652
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 5440,
#                         "endTimeMs": 5960,
#                         "text": "Come here, girl.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     },
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 5960,
#                         "endTimeMs": 6120,
#                         "text": "Stop.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:06.298 => 00:07.591\n## Transcript\n```\nWEBVTT\n\n00:06.800 --> 00:07.720\n<v Speaker>Let go.\n```\n## Key Frames\n- 00:06.962 ![](keyFrame.6962.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "An older man is seen sitting inside a vehicle, gripping the steering wheel. He appears to be observing the situation unfolding outside, possibly with concern or intent to intervene."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 6298,
#                 "endTimeMs": 7591,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     6962
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 6800,
#                         "endTimeMs": 7720,
#                         "text": "Let go.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:07.591 => 00:11.385\n## Transcript\n```\nWEBVTT\n\n00:06.800 --> 00:07.720\n<v Speaker>Let go.\n00:08.880 --> 00:10.080\n<v Speaker>What you looking at, old man?\n00:10.760 --> 00:14.760\n<v Speaker>Never knows how you come across somebody once in a while you shouldn't have messed with.\n```\n## Key Frames\n- 00:08.314 ![](keyFrame.8314.jpg)\n- 00:09.051 ![](keyFrame.9051.jpg)\n- 00:09.788 ![](keyFrame.9788.jpg)\n- 00:10.526 ![](keyFrame.10526.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The logo for Village Roadshow Pictures is displayed on screen, indicating their involvement in the production of the film. The logo appears against a dark background, adding to the cinematic atmosphere."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 7591,
#                 "endTimeMs": 11386,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     8314,
#                     9051,
#                     9788,
#                     10526
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 6800,
#                         "endTimeMs": 7720,
#                         "text": "Let go.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     },
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 8880,
#                         "endTimeMs": 10080,
#                         "text": "What you looking at, old man?",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     },
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 10760,
#                         "endTimeMs": 14760,
#                         "text": "Never knows how you come across somebody once in a while you shouldn't have messed with.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:11.385 => 00:13.347\n## Transcript\n```\nWEBVTT\n\n00:10.760 --> 00:14.760\n<v Speaker>Never knows how you come across somebody once in a while you shouldn't have messed with.\n```\n## Key Frames\n- 00:12.041 ![](keyFrame.12041.jpg)\n- 00:12.696 ![](keyFrame.12696.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The scene returns to the street where the older man has now exited his vehicle and is facing a group of young men. His posture suggests he is confronting them or addressing the situation observed earlier."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 11386,
#                 "endTimeMs": 13347,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     12041,
#                     12696
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 10760,
#                         "endTimeMs": 14760,
#                         "text": "Never knows how you come across somebody once in a while you shouldn't have messed with.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:13.347 => 00:14.515\n## Transcript\n```\nWEBVTT\n\n00:10.760 --> 00:14.760\n<v Speaker>Never knows how you come across somebody once in a while you shouldn't have messed with.\n```\n## Key Frames\n- 00:13.925 ![](keyFrame.13925.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The camera captures a wider shot of the group of young men standing in front of a building with the number '13110' visible. The older man faces them, creating an intense standoff moment."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 13347,
#                 "endTimeMs": 14515,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     13925
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 10760,
#                         "endTimeMs": 14760,
#                         "text": "Never knows how you come across somebody once in a while you shouldn't have messed with.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:14.515 => 00:15.682\n## Transcript\n```\nWEBVTT\n\n00:10.760 --> 00:14.760\n<v Speaker>Never knows how you come across somebody once in a while you shouldn't have messed with.\n```\n## Key Frames\n- 00:15.113 ![](keyFrame.15113.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The screen momentarily goes black, possibly indicating a transition or change in scene focus."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 14515,
#                 "endTimeMs": 15682,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     15113
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 10760,
#                         "endTimeMs": 14760,
#                         "text": "Never knows how you come across somebody once in a while you shouldn't have messed with.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:15.724 => 00:16.725\n## Transcript\n```\nWEBVTT\n\n00:15.760 --> 00:16.480\n<v Speaker>That's me.\n```\n## Key Frames\n- 00:15.727 ![](keyFrame.15727.jpg)\n- 00:16.218 ![](keyFrame.16218.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The older man is seen facing one of the young men, conveying a sense of authority or confrontation as he stands firm in front of his vehicle."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 15724,
#                 "endTimeMs": 16725,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     15727,
#                     16218
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 15760,
#                         "endTimeMs": 16480,
#                         "text": "That's me.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:16.725 => 00:18.477\n## Transcript\n```\nWEBVTT\n\n00:17.040 --> 00:17.760\n<v Speaker>Man, you crazy, man.\n00:17.760 --> 00:18.480\n<v Speaker>Get out of here, man.\n```\n## Key Frames\n- 00:17.283 ![](keyFrame.17283.jpg)\n- 00:17.857 ![](keyFrame.17857.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A young man in a striped tank top gestures with his hand, possibly in response to the older man's presence or statements. The group seems to be reacting to the ongoing situation."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 16725,
#                 "endTimeMs": 18477,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     17283,
#                     17857
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 17040,
#                         "endTimeMs": 17760,
#                         "text": "Man, you crazy, man.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     },
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 17760,
#                         "endTimeMs": 18480,
#                         "text": "Get out of here, man.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:18.477 => 00:19.393\n## Transcript\n```\nWEBVTT\n\n00:17.760 --> 00:18.480\n<v Speaker>Get out of here, man.\n```\n## Key Frames\n- 00:18.962 ![](keyFrame.18962.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The older man gestures with his hand as if making a point or responding to the young man's gesture, maintaining a firm stance in the confrontation."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 18477,
#                 "endTimeMs": 19394,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     18962
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 17760,
#                         "endTimeMs": 18480,
#                         "text": "Get out of here, man.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:19.393 => 00:23.315\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 00:20.191 ![](keyFrame.20191.jpg)\n- 00:20.969 ![](keyFrame.20969.jpg)\n- 00:21.747 ![](keyFrame.21747.jpg)\n- 00:22.526 ![](keyFrame.22526.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The segment showcases a series of credits introducing the director, Clint Eastwood. The text gradually appears on a black screen, creating a dramatic and anticipatory atmosphere."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 19394,
#                 "endTimeMs": 23315,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     20191,
#                     20969,
#                     21747,
#                     22526
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 00:23.315 => 00:24.358\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 00:23.836 ![](keyFrame.23836.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A scenic view unfolds, revealing a classic car driving along a picturesque lakeside road. The scene captures the beauty of the landscape, suggesting a peaceful and leisurely pace."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 23315,
#                 "endTimeMs": 24358,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     23836
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 00:24.358 => 00:26.443\n## Transcript\n```\nWEBVTT\n\n00:26.240 --> 00:27.600\n<v Speaker>Dad, you worked hard your whole life.\n```\n## Key Frames\n- 00:25.065 ![](keyFrame.25065.jpg)\n- 00:25.761 ![](keyFrame.25761.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A close-up shot of a person cleaning a 'Gran Torino Sport' car with a cloth. This action highlights attention to detail and care for the vehicle, suggesting a sense of pride and ownership."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 24358,
#                 "endTimeMs": 26443,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     25065,
#                     25761
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 26240,
#                         "endTimeMs": 27600,
#                         "text": "Dad, you worked hard your whole life.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:26.443 => 00:27.819\n## Transcript\n```\nWEBVTT\n\n00:26.240 --> 00:27.600\n<v Speaker>Dad, you worked hard your whole life.\n```\n## Key Frames\n- 00:27.154 ![](keyFrame.27154.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The camera focuses on a beautifully decorated birthday cake with the words 'Happy Birthday Dad' written in blue frosting. This sets a celebratory and familial tone."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 26443,
#                 "endTimeMs": 27819,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     27154
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 26240,
#                         "endTimeMs": 27600,
#                         "text": "Dad, you worked hard your whole life.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:27.819 => 00:29.154\n## Transcript\n```\nWEBVTT\n\n00:27.920 --> 00:30.560\n<v Speaker>Maybe it's time you started thinking about taking it easier.\n```\n## Key Frames\n- 00:28.505 ![](keyFrame.28505.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "Inside a warmly lit room, an individual stands up from a chair, possibly preparing to speak or engage with others in the setting."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 27819,
#                 "endTimeMs": 29154,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     28505
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 27920,
#                         "endTimeMs": 30560,
#                         "text": "Maybe it's time you started thinking about taking it easier.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:29.154 => 00:30.781\n## Transcript\n```\nWEBVTT\n\n00:27.920 --> 00:30.560\n<v Speaker>Maybe it's time you started thinking about taking it easier.\n```\n## Key Frames\n- 00:29.693 ![](keyFrame.29693.jpg)\n- 00:30.225 ![](keyFrame.30225.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The scene shifts to a person seated at a dining table, listening intently, indicating a conversation or discussion is taking place."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 29154,
#                 "endTimeMs": 30781,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     29693,
#                     30225
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 27920,
#                         "endTimeMs": 30560,
#                         "text": "Maybe it's time you started thinking about taking it easier.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:30.781 => 00:32.658\n## Transcript\n```\nWEBVTT\n\n00:30.880 --> 00:33.680\n<v Speaker>These places are nothing like what you'd think they'd be.\n```\n## Key Frames\n- 00:31.413 ![](keyFrame.31413.jpg)\n- 00:32.027 ![](keyFrame.32027.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The camera captures a hand sifting through brochures titled 'Retire in Style' and 'Senior Living Communities,' suggesting a discussion about retirement or lifestyle changes."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 30781,
#                 "endTimeMs": 32658,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     31413,
#                     32027
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 30880,
#                         "endTimeMs": 33680,
#                         "text": "These places are nothing like what you'd think they'd be.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:32.658 => 00:33.867\n## Transcript\n```\nWEBVTT\n\n00:30.880 --> 00:33.680\n<v Speaker>These places are nothing like what you'd think they'd be.\n00:33.840 --> 00:34.400\n<v Speaker>They're great.\n```\n## Key Frames\n- 00:33.256 ![](keyFrame.33256.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A woman enters the room, engaging with the individuals present. Her entrance suggests she might be joining or contributing to an ongoing conversation."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 32658,
#                 "endTimeMs": 33867,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     33256
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 30880,
#                         "endTimeMs": 33680,
#                         "text": "These places are nothing like what you'd think they'd be.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     },
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 33840,
#                         "endTimeMs": 34400,
#                         "text": "They're great.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:33.867 => 00:35.369\n## Transcript\n```\nWEBVTT\n\n00:33.840 --> 00:34.400\n<v Speaker>They're great.\n```\n## Key Frames\n- 00:34.362 ![](keyFrame.34362.jpg)\n- 00:34.853 ![](keyFrame.34853.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The focus returns to the person seated at the table, showing a moment of contemplation or consideration as they listen."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 33867,
#                 "endTimeMs": 35369,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     34362,
#                     34853
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 33840,
#                         "endTimeMs": 34400,
#                         "text": "They're great.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:35.369 => 00:35.744\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 00:35.590 ![](keyFrame.35590.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The segment concludes with a brief fade to black, signaling a transition or pause in the narrative."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 35369,
#                 "endTimeMs": 35744,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     35590
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 00:35.744 => 00:40.540\n## Transcript\n```\nWEBVTT\n\n00:36.240 --> 00:37.240\n<v Speaker>Kicking us out on his birthday.\n00:37.240 --> 00:38.480\n<v Speaker>I told you this was a bad idea.\n00:38.480 --> 00:40.480\n<v Speaker>What the hell?\n00:40.480 --> 00:42.720\n<v Speaker>These Chinese after moving this they rode for.\n```\n## Key Frames\n- 00:36.532 ![](keyFrame.36532.jpg)\n- 00:37.311 ![](keyFrame.37311.jpg)\n- 00:38.089 ![](keyFrame.38089.jpg)\n- 00:38.867 ![](keyFrame.38867.jpg)\n- 00:39.645 ![](keyFrame.39645.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A man and a woman are standing on the porch of a house, appearing to be in conversation. The man is dressed in a casual polo shirt, while the woman is wearing a black outfit with pearls. They are seen descending the steps of the house, suggesting they might be leaving or having just exited. The scene transitions to a wider shot of the house from across the street, showing a well-maintained lawn and neighboring houses."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 35744,
#                 "endTimeMs": 40541,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     36532,
#                     37311,
#                     38089,
#                     38867,
#                     39645
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 36240,
#                         "endTimeMs": 37240,
#                         "text": "Kicking us out on his birthday.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     },
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 37240,
#                         "endTimeMs": 38480,
#                         "text": "I told you this was a bad idea.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     },
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 38480,
#                         "endTimeMs": 40480,
#                         "text": "What the hell?",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     },
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 40480,
#                         "endTimeMs": 42720,
#                         "text": "These Chinese after moving this they rode for.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:40.540 => 00:41.415\n## Transcript\n```\nWEBVTT\n\n00:40.480 --> 00:42.720\n<v Speaker>These Chinese after moving this they rode for.\n```\n## Key Frames\n- 00:40.997 ![](keyFrame.40997.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "An older man is seen standing outside on the sidewalk, in front of a house with an American flag displayed. He appears to be looking towards the camera or someone off-screen."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 40541,
#                 "endTimeMs": 41416,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     40997
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 40480,
#                         "endTimeMs": 42720,
#                         "text": "These Chinese after moving this they rode for.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:41.415 => 00:42.834\n## Transcript\n```\nWEBVTT\n\n00:40.480 --> 00:42.720\n<v Speaker>These Chinese after moving this they rode for.\n```\n## Key Frames\n- 00:42.143 ![](keyFrame.42143.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A woman, wearing a large sun hat and a brown cardigan, emerges from a house, looking towards the camera or someone nearby. The background shows a wall with potted plants, indicating a residential setting."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 41416,
#                 "endTimeMs": 42834,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     42143
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 40480,
#                         "endTimeMs": 42720,
#                         "text": "These Chinese after moving this they rode for.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:42.834 => 00:44.753\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 00:43.495 ![](keyFrame.43495.jpg)\n- 00:44.150 ![](keyFrame.44150.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The older man from the previous segment is shown again, standing outside. His posture and expression suggest he might be engaging in or preparing for a conversation."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 42834,
#                 "endTimeMs": 44753,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     43495,
#                     44150
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 00:44.753 => 00:46.088\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 00:45.420 ![](keyFrame.45420.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The woman with the sun hat is shown again, sitting down, possibly on a porch or outdoor seating area, with a relaxed demeanor."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 44753,
#                 "endTimeMs": 46088,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     45420
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 00:46.088 => 00:49.007\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 00:46.812 ![](keyFrame.46812.jpg)\n- 00:47.549 ![](keyFrame.47549.jpg)\n- 00:48.287 ![](keyFrame.48287.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The older man is once again seen standing outside, with a slight shift in his position. The scene transitions to an interior of a church, with a congregation seated in pews, indicating a formal gathering or service."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 46088,
#                 "endTimeMs": 49007,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     46812,
#                     47549,
#                     48287
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 00:49.007 => 00:50.676\n## Transcript\n```\nWEBVTT\n\n00:49.120 --> 00:52.880\n<v Speaker>Dorothy mentioned specifically that it was her desire for you to go to confession.\n```\n## Key Frames\n- 00:49.556 ![](keyFrame.49556.jpg)\n- 00:50.089 ![](keyFrame.50089.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "Inside the church, a group of people is seated in the pews. The atmosphere is somber, suggesting a service or ceremony is taking place. The attendees are dressed in formal attire, indicating the seriousness of the occasion."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 49007,
#                 "endTimeMs": 50676,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     49556,
#                     50089
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 49120,
#                         "endTimeMs": 52880,
#                         "text": "Dorothy mentioned specifically that it was her desire for you to go to confession.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:50.676 => 00:51.510\n## Transcript\n```\nWEBVTT\n\n00:49.120 --> 00:52.880\n<v Speaker>Dorothy mentioned specifically that it was her desire for you to go to confession.\n```\n## Key Frames\n- 00:51.113 ![](keyFrame.51113.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The scene briefly cuts to black, maintaining the somber and contemplative mood established earlier."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 50676,
#                 "endTimeMs": 51510,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     51113
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 49120,
#                         "endTimeMs": 52880,
#                         "text": "Dorothy mentioned specifically that it was her desire for you to go to confession.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:51.552 => 00:52.928\n## Transcript\n```\nWEBVTT\n\n00:49.120 --> 00:52.880\n<v Speaker>Dorothy mentioned specifically that it was her desire for you to go to confession.\n```\n## Key Frames\n- 00:51.563 ![](keyFrame.51563.jpg)\n- 00:52.259 ![](keyFrame.52259.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "Inside a dimly lit room, people are seen conversing. The atmosphere suggests a gathering or reception, possibly related to the earlier church service."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 51552,
#                 "endTimeMs": 52928,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     51563,
#                     52259
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 49120,
#                         "endTimeMs": 52880,
#                         "text": "Dorothy mentioned specifically that it was her desire for you to go to confession.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:52.928 => 00:57.724\n## Transcript\n```\nWEBVTT\n\n00:53.000 --> 00:57.840\n<v Speaker>And I confess that I have no desire to confess to a boy that's just out of the seminary.\n```\n## Key Frames\n- 00:53.693 ![](keyFrame.53693.jpg)\n- 00:54.471 ![](keyFrame.54471.jpg)\n- 00:55.249 ![](keyFrame.55249.jpg)\n- 00:56.027 ![](keyFrame.56027.jpg)\n- 00:56.805 ![](keyFrame.56805.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A conversation takes place between two individuals, one of whom expresses reluctance to confess to someone just out of the seminary. The setting appears to be a dimly lit room with a window in the background. The tone seems serious and contemplative."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 52928,
#                 "endTimeMs": 57724,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     53693,
#                     54471,
#                     55249,
#                     56027,
#                     56805
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 53000,
#                         "endTimeMs": 57840,
#                         "text": "And I confess that I have no desire to confess to a boy that's just out of the seminary.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 00:57.724 => 01:01.228\n## Transcript\n```\nWEBVTT\n\n00:53.000 --> 00:57.840\n<v Speaker>And I confess that I have no desire to confess to a boy that's just out of the seminary.\n```\n## Key Frames\n- 00:58.403 ![](keyFrame.58403.jpg)\n- 00:59.099 ![](keyFrame.59099.jpg)\n- 00:59.795 ![](keyFrame.59795.jpg)\n- 01:00.491 ![](keyFrame.60491.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The scene transitions to a crowded room filled with people moving around. There is a sense of social gathering or event, with individuals engaged in conversation and interaction. The lighting is warm, suggesting an indoor setting."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 57724,
#                 "endTimeMs": 61228,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     58403,
#                     59099,
#                     59795,
#                     60491
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 53000,
#                         "endTimeMs": 57840,
#                         "text": "And I confess that I have no desire to confess to a boy that's just out of the seminary.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
# ...
#                         "startTimeMs": 124400,
#                         "endTimeMs": 125360,
#                         "text": "You don't want to know.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 02:05.709 => 02:06.251\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 02:05.980 ![](keyFrame.125980.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The screen momentarily goes black, creating a pause or transition in the scene, potentially heightening suspense."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 125709,
#                 "endTimeMs": 126251,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     125980
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 02:06.251 => 02:07.419\n## Transcript\n```\nWEBVTT\n\n02:07.200 --> 02:11.840\n<v Speaker>Tao and Sue are never going to find peace in this world as long as that gang's around.\n```\n## Key Frames\n- 02:06.840 ![](keyFrame.126840.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The scene shifts to a dark interior of a car, with minimal visibility, enhancing a mood of secrecy or impending action."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 126251,
#                 "endTimeMs": 127419,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     126840
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 127200,
#                         "endTimeMs": 131840,
#                         "text": "Tao and Sue are never going to find peace in this world as long as that gang's around.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 02:07.419 => 02:08.544\n## Transcript\n```\nWEBVTT\n\n02:07.200 --> 02:11.840\n<v Speaker>Tao and Sue are never going to find peace in this world as long as that gang's around.\n```\n## Key Frames\n- 02:07.986 ![](keyFrame.127986.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "Two young individuals, possibly Tao and Sue, are standing outside with police lights flashing in the background, indicating a situation involving law enforcement."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 127419,
#                 "endTimeMs": 128545,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     127986
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 127200,
#                         "endTimeMs": 131840,
#                         "text": "Tao and Sue are never going to find peace in this world as long as that gang's around.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 02:08.544 => 02:10.380\n## Transcript\n```\nWEBVTT\n\n02:07.200 --> 02:11.840\n<v Speaker>Tao and Sue are never going to find peace in this world as long as that gang's around.\n```\n## Key Frames\n- 02:09.174 ![](keyFrame.129174.jpg)\n- 02:09.788 ![](keyFrame.129788.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A man sits in a darkened room, partially illuminated, suggesting deep thought or contemplation about past or future actions."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 128545,
#                 "endTimeMs": 130380,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     129174,
#                     129788
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 127200,
#                         "endTimeMs": 131840,
#                         "text": "Tao and Sue are never going to find peace in this world as long as that gang's around.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 02:10.380 => 02:11.548\n## Transcript\n```\nWEBVTT\n\n02:07.200 --> 02:11.840\n<v Speaker>Tao and Sue are never going to find peace in this world as long as that gang's around.\n```\n## Key Frames\n- 02:10.976 ![](keyFrame.130976.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A car filled with individuals, one of whom has a bandana on his head, drives by, suggesting the presence of gang members or a tense situation involving this group."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 130380,
#                 "endTimeMs": 131548,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     130976
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 127200,
#                         "endTimeMs": 131840,
#                         "text": "Tao and Sue are never going to find peace in this world as long as that gang's around.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 02:11.548 => 02:14.550\n## Transcript\n```\nWEBVTT\n\n02:07.200 --> 02:11.840\n<v Speaker>Tao and Sue are never going to find peace in this world as long as that gang's around.\n02:11.840 --> 02:13.360\n<v Speaker>What are you going to do, Walt?\n```\n## Key Frames\n- 02:12.287 ![](keyFrame.132287.jpg)\n- 02:13.024 ![](keyFrame.133024.jpg)\n- 02:13.761 ![](keyFrame.133761.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The scene transitions to a dimly lit room where a man appears to be listening intently or preparing to speak, with the atmosphere conveying tension."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 131548,
#                 "endTimeMs": 134551,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     132287,
#                     133024,
#                     133761
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 127200,
#                         "endTimeMs": 131840,
#                         "text": "Tao and Sue are never going to find peace in this world as long as that gang's around.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     },
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 131840,
#                         "endTimeMs": 133360,
#                         "text": "What are you going to do, Walt?",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 02:14.550 => 02:15.844\n## Transcript\n```\nWEBVTT\n\n02:14.800 --> 02:15.840\n<v Speaker>Whatever it is.\n```\n## Key Frames\n- 02:15.195 ![](keyFrame.135195.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A man stands on a porch in daylight, gazing outward, possibly contemplating a significant decision or observing a situation unfolding."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 134551,
#                 "endTimeMs": 135844,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     135195
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 134800,
#                         "endTimeMs": 135840,
#                         "text": "Whatever it is.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 02:15.844 => 02:17.095\n## Transcript\n```\nWEBVTT\n\n02:16.520 --> 02:17.760\n<v Speaker>They won't have a chance.\n```\n## Key Frames\n- 02:16.464 ![](keyFrame.136464.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "A car is driving down a street, suggesting movement or an ongoing pursuit, possibly linked to previous events involving a gang."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 135844,
#                 "endTimeMs": 137095,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     136464
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 136520,
#                         "endTimeMs": 137760,
#                         "text": "They won't have a chance.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 02:17.095 => 02:18.305\n## Transcript\n```\nWEBVTT\n\n02:16.520 --> 02:17.760\n<v Speaker>They won't have a chance.\n```\n## Key Frames\n- 02:17.693 ![](keyFrame.137693.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The man on the porch extends his arm, possibly pointing or gesturing in response to something seen on the street."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 137095,
#                 "endTimeMs": 138305,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     137693
#                 ],
#                 "transcriptPhrases": [
#                     {
#                         "speaker": "speaker",
#                         "startTimeMs": 136520,
#                         "endTimeMs": 137760,
#                         "text": "They won't have a chance.",
#                         "confidence": 1,
#                         "words": [],
#                         "locale": "en-US"
#                     }
#                 ]
#             },
#             {
#                 "markdown": "# Shot 02:18.305 => 02:21.933\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 02:19.044 ![](keyFrame.139044.jpg)\n- 02:19.782 ![](keyFrame.139782.jpg)\n- 02:20.519 ![](keyFrame.140519.jpg)\n- 02:21.256 ![](keyFrame.141256.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The title 'GRAN TORINO' appears on the screen, indicating the film's title, accompanied by a dramatic pause or musical cue."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 138305,
#                 "endTimeMs": 141933,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     139044,
#                     139782,
#                     140519,
#                     141256
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 02:21.933 => 02:22.851\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 02:22.403 ![](keyFrame.142403.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The production credits begin to appear against a dark background, listing the production companies and key contributors to the film."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 141933,
#                 "endTimeMs": 142851,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     142403
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 02:22.851 => 02:23.894\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 02:23.386 ![](keyFrame.143386.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The segment displays the closing credits of a film, highlighting key contributors. It lists David Johannson and Nick Schenk for story, Nick Schenk for screenplay, Robert Lorenz and Bill Gerber for production, and Clint Eastwood for direction. The film's website and production company, Warner Bros., are also mentioned."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 142851,
#                 "endTimeMs": 143894,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     143386
#                 ],
#                 "transcriptPhrases": []
#             },
#             {
#                 "markdown": "# Shot 02:23.894 => 02:24.895\n## Transcript\n```\nWEBVTT\n\n```\n## Key Frames\n- 02:24.410 ![](keyFrame.144410.jpg)",
#                 "fields": {
#                     "segmentDescription": {
#                         "type": "string",
#                         "valueString": "The screen transitions to black, marking the end of the closing credits. This indicates the conclusion of the video content."
#                     }
#                 },
#                 "kind": "audioVisual",
#                 "startTimeMs": 143894,
#                 "endTimeMs": 144895,
#                 "width": 1280,
#                 "height": 534,
#                 "KeyFrameTimesMs": [
#                     144410
#                 ],
#                 "transcriptPhrases": []
#             }
#         ]
#     }
# }

# %% [markdown]
# ### Pre-process the video segmentation descriptions with Azure Content Understanding

# %%
segments = get_scene_description(video_result)
print(f"Number of documents: {len(segments)} segments.")
# Out:
# Number of documents: 102 segments.

# %%
for i, segment in enumerate(segments, start=1):
    print("\033[1;31;34m")
    print(f"Scene {i}: {segment.page_content}")
# Out:
# Scene 1: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The video opens with the iconic Warner Bros. Pictures logo, signaling the beginning of a movie. The logo is presented in its typical format, showing the emblem with the text "A TimeWarner Company" beneath it.'}}, 'kind': 'audioVisual', 'startTimeMs': 0, 'endTimeMs': 1418, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [737], 'transcriptPhrases': []}```
#
# Scene 2: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The Warner Bros. Pictures logo fades out, and the screen transitions to black, maintaining a sense of anticipation for what is to follow.'}}, 'kind': 'audioVisual', 'startTimeMs': 1418, 'endTimeMs': 3253, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [2048, 2662], 'transcriptPhrases': []}```
#
# Scene 3: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A scene is shown depicting a quiet urban street corner. A white pickup truck drives past a stop sign, and a group of individuals can be seen standing near a brick building. The street is lined with houses and appears to be a typical suburban area.'}}, 'kind': 'audioVisual', 'startTimeMs': 3253, 'endTimeMs': 4963, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [3809, 4382], 'transcriptPhrases': []}```
#
# Scene 4: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A tense moment is captured as a young woman is being grabbed by the arm by a man, indicating a possible confrontation or struggle. Several other individuals are present in the scene, observing the interaction.'}}, 'kind': 'audioVisual', 'startTimeMs': 4963, 'endTimeMs': 6298, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [5652], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 5440, 'endTimeMs': 5960, 'text': 'Come here, girl.', 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 5960, 'endTimeMs': 6120, 'text': 'Stop.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 5: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'An older man is seen sitting inside a vehicle, gripping the steering wheel. He appears to be observing the situation unfolding outside, possibly with concern or intent to intervene.'}}, 'kind': 'audioVisual', 'startTimeMs': 6298, 'endTimeMs': 7591, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [6962], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 6800, 'endTimeMs': 7720, 'text': 'Let go.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 6: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The logo for Village Roadshow Pictures is displayed on screen, indicating their involvement in the production of the film. The logo appears against a dark background, adding to the cinematic atmosphere.'}}, 'kind': 'audioVisual', 'startTimeMs': 7591, 'endTimeMs': 11386, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [8314, 9051, 9788, 10526], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 6800, 'endTimeMs': 7720, 'text': 'Let go.', 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 8880, 'endTimeMs': 10080, 'text': 'What you looking at, old man?', 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 10760, 'endTimeMs': 14760, 'text': "Never knows how you come across somebody once in a while you shouldn't have messed with.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 7: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene returns to the street where the older man has now exited his vehicle and is facing a group of young men. His posture suggests he is confronting them or addressing the situation observed earlier.'}}, 'kind': 'audioVisual', 'startTimeMs': 11386, 'endTimeMs': 13347, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [12041, 12696], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 10760, 'endTimeMs': 14760, 'text': "Never knows how you come across somebody once in a while you shouldn't have messed with.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 8: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': "The camera captures a wider shot of the group of young men standing in front of a building with the number '13110' visible. The older man faces them, creating an intense standoff moment."}}, 'kind': 'audioVisual', 'startTimeMs': 13347, 'endTimeMs': 14515, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [13925], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 10760, 'endTimeMs': 14760, 'text': "Never knows how you come across somebody once in a while you shouldn't have messed with.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 9: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The screen momentarily goes black, possibly indicating a transition or change in scene focus.'}}, 'kind': 'audioVisual', 'startTimeMs': 14515, 'endTimeMs': 15682, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [15113], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 10760, 'endTimeMs': 14760, 'text': "Never knows how you come across somebody once in a while you shouldn't have messed with.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 10: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The older man is seen facing one of the young men, conveying a sense of authority or confrontation as he stands firm in front of his vehicle.'}}, 'kind': 'audioVisual', 'startTimeMs': 15724, 'endTimeMs': 16725, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [15727, 16218], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 15760, 'endTimeMs': 16480, 'text': "That's me.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 11: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': "A young man in a striped tank top gestures with his hand, possibly in response to the older man's presence or statements. The group seems to be reacting to the ongoing situation."}}, 'kind': 'audioVisual', 'startTimeMs': 16725, 'endTimeMs': 18477, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [17283, 17857], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 17040, 'endTimeMs': 17760, 'text': 'Man, you crazy, man.', 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 17760, 'endTimeMs': 18480, 'text': 'Get out of here, man.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 12: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': "The older man gestures with his hand as if making a point or responding to the young man's gesture, maintaining a firm stance in the confrontation."}}, 'kind': 'audioVisual', 'startTimeMs': 18477, 'endTimeMs': 19394, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [18962], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 17760, 'endTimeMs': 18480, 'text': 'Get out of here, man.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 13: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The segment showcases a series of credits introducing the director, Clint Eastwood. The text gradually appears on a black screen, creating a dramatic and anticipatory atmosphere.'}}, 'kind': 'audioVisual', 'startTimeMs': 19394, 'endTimeMs': 23315, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [20191, 20969, 21747, 22526], 'transcriptPhrases': []}```
#
# Scene 14: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A scenic view unfolds, revealing a classic car driving along a picturesque lakeside road. The scene captures the beauty of the landscape, suggesting a peaceful and leisurely pace.'}}, 'kind': 'audioVisual', 'startTimeMs': 23315, 'endTimeMs': 24358, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [23836], 'transcriptPhrases': []}```
#
# Scene 15: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': "A close-up shot of a person cleaning a 'Gran Torino Sport' car with a cloth. This action highlights attention to detail and care for the vehicle, suggesting a sense of pride and ownership."}}, 'kind': 'audioVisual', 'startTimeMs': 24358, 'endTimeMs': 26443, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [25065, 25761], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 26240, 'endTimeMs': 27600, 'text': 'Dad, you worked hard your whole life.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 16: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': "The camera focuses on a beautifully decorated birthday cake with the words 'Happy Birthday Dad' written in blue frosting. This sets a celebratory and familial tone."}}, 'kind': 'audioVisual', 'startTimeMs': 26443, 'endTimeMs': 27819, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [27154], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 26240, 'endTimeMs': 27600, 'text': 'Dad, you worked hard your whole life.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 17: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Inside a warmly lit room, an individual stands up from a chair, possibly preparing to speak or engage with others in the setting.'}}, 'kind': 'audioVisual', 'startTimeMs': 27819, 'endTimeMs': 29154, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [28505], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 27920, 'endTimeMs': 30560, 'text': "Maybe it's time you started thinking about taking it easier.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 18: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene shifts to a person seated at a dining table, listening intently, indicating a conversation or discussion is taking place.'}}, 'kind': 'audioVisual', 'startTimeMs': 29154, 'endTimeMs': 30781, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [29693, 30225], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 27920, 'endTimeMs': 30560, 'text': "Maybe it's time you started thinking about taking it easier.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 19: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': "The camera captures a hand sifting through brochures titled 'Retire in Style' and 'Senior Living Communities,' suggesting a discussion about retirement or lifestyle changes."}}, 'kind': 'audioVisual', 'startTimeMs': 30781, 'endTimeMs': 32658, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [31413, 32027], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 30880, 'endTimeMs': 33680, 'text': "These places are nothing like what you'd think they'd be.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 20: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A woman enters the room, engaging with the individuals present. Her entrance suggests she might be joining or contributing to an ongoing conversation.'}}, 'kind': 'audioVisual', 'startTimeMs': 32658, 'endTimeMs': 33867, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [33256], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 30880, 'endTimeMs': 33680, 'text': "These places are nothing like what you'd think they'd be.", 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 33840, 'endTimeMs': 34400, 'text': "They're great.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 21: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The focus returns to the person seated at the table, showing a moment of contemplation or consideration as they listen.'}}, 'kind': 'audioVisual', 'startTimeMs': 33867, 'endTimeMs': 35369, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [34362, 34853], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 33840, 'endTimeMs': 34400, 'text': "They're great.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 22: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The segment concludes with a brief fade to black, signaling a transition or pause in the narrative.'}}, 'kind': 'audioVisual', 'startTimeMs': 35369, 'endTimeMs': 35744, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [35590], 'transcriptPhrases': []}```
#
# Scene 23: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A man and a woman are standing on the porch of a house, appearing to be in conversation. The man is dressed in a casual polo shirt, while the woman is wearing a black outfit with pearls. They are seen descending the steps of the house, suggesting they might be leaving or having just exited. The scene transitions to a wider shot of the house from across the street, showing a well-maintained lawn and neighboring houses.'}}, 'kind': 'audioVisual', 'startTimeMs': 35744, 'endTimeMs': 40541, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [36532, 37311, 38089, 38867, 39645], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 36240, 'endTimeMs': 37240, 'text': 'Kicking us out on his birthday.', 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 37240, 'endTimeMs': 38480, 'text': 'I told you this was a bad idea.', 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 38480, 'endTimeMs': 40480, 'text': 'What the hell?', 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 40480, 'endTimeMs': 42720, 'text': 'These Chinese after moving this they rode for.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 24: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'An older man is seen standing outside on the sidewalk, in front of a house with an American flag displayed. He appears to be looking towards the camera or someone off-screen.'}}, 'kind': 'audioVisual', 'startTimeMs': 40541, 'endTimeMs': 41416, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [40997], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 40480, 'endTimeMs': 42720, 'text': 'These Chinese after moving this they rode for.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 25: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A woman, wearing a large sun hat and a brown cardigan, emerges from a house, looking towards the camera or someone nearby. The background shows a wall with potted plants, indicating a residential setting.'}}, 'kind': 'audioVisual', 'startTimeMs': 41416, 'endTimeMs': 42834, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [42143], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 40480, 'endTimeMs': 42720, 'text': 'These Chinese after moving this they rode for.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 26: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The older man from the previous segment is shown again, standing outside. His posture and expression suggest he might be engaging in or preparing for a conversation.'}}, 'kind': 'audioVisual', 'startTimeMs': 42834, 'endTimeMs': 44753, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [43495, 44150], 'transcriptPhrases': []}```
#
# Scene 27: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The woman with the sun hat is shown again, sitting down, possibly on a porch or outdoor seating area, with a relaxed demeanor.'}}, 'kind': 'audioVisual', 'startTimeMs': 44753, 'endTimeMs': 46088, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [45420], 'transcriptPhrases': []}```
#
# Scene 28: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The older man is once again seen standing outside, with a slight shift in his position. The scene transitions to an interior of a church, with a congregation seated in pews, indicating a formal gathering or service.'}}, 'kind': 'audioVisual', 'startTimeMs': 46088, 'endTimeMs': 49007, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [46812, 47549, 48287], 'transcriptPhrases': []}```
#
# Scene 29: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Inside the church, a group of people is seated in the pews. The atmosphere is somber, suggesting a service or ceremony is taking place. The attendees are dressed in formal attire, indicating the seriousness of the occasion.'}}, 'kind': 'audioVisual', 'startTimeMs': 49007, 'endTimeMs': 50676, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [49556, 50089], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 49120, 'endTimeMs': 52880, 'text': 'Dorothy mentioned specifically that it was her desire for you to go to confession.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 30: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene briefly cuts to black, maintaining the somber and contemplative mood established earlier.'}}, 'kind': 'audioVisual', 'startTimeMs': 50676, 'endTimeMs': 51510, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [51113], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 49120, 'endTimeMs': 52880, 'text': 'Dorothy mentioned specifically that it was her desire for you to go to confession.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 31: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Inside a dimly lit room, people are seen conversing. The atmosphere suggests a gathering or reception, possibly related to the earlier church service.'}}, 'kind': 'audioVisual', 'startTimeMs': 51552, 'endTimeMs': 52928, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [51563, 52259], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 49120, 'endTimeMs': 52880, 'text': 'Dorothy mentioned specifically that it was her desire for you to go to confession.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 32: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A conversation takes place between two individuals, one of whom expresses reluctance to confess to someone just out of the seminary. The setting appears to be a dimly lit room with a window in the background. The tone seems serious and contemplative.'}}, 'kind': 'audioVisual', 'startTimeMs': 52928, 'endTimeMs': 57724, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [53693, 54471, 55249, 56027, 56805], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 53000, 'endTimeMs': 57840, 'text': "And I confess that I have no desire to confess to a boy that's just out of the seminary.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 33: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene transitions to a crowded room filled with people moving around. There is a sense of social gathering or event, with individuals engaged in conversation and interaction. The lighting is warm, suggesting an indoor setting.'}}, 'kind': 'audioVisual', 'startTimeMs': 57724, 'endTimeMs': 61228, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [58403, 59099, 59795, 60491], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 53000, 'endTimeMs': 57840, 'text': "And I confess that I have no desire to confess to a boy that's just out of the seminary.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 34: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene shifts to the exterior of a house at night. A car is parked in front, and the porch is dimly lit, creating a calm and quiet atmosphere.'}}, 'kind': 'audioVisual', 'startTimeMs': 61228, 'endTimeMs': 62521, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [61884], 'transcriptPhrases': []}```
#
# Scene 35: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The screen goes dark, possibly indicating a transition or a pause between scenes.'}}, 'kind': 'audioVisual', 'startTimeMs': 62521, 'endTimeMs': 63230, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [62908], 'transcriptPhrases': []}```
#
# Scene 36: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A person is seen lying in bed, illuminated by stripes of light filtering through blinds. The person appears to be waking up or adjusting in the bed, suggesting a moment of rest or contemplation.'}}, 'kind': 'audioVisual', 'startTimeMs': 63230, 'endTimeMs': 65774, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [63850, 64464, 65078], 'transcriptPhrases': []}```
#
# Scene 37: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Outside a house at night, a group of people are gathered on the porch. The scene suggests an urgent or emotional moment as individuals appear to be comforting or supporting each other.'}}, 'kind': 'audioVisual', 'startTimeMs': 65774, 'endTimeMs': 66984, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [66389], 'transcriptPhrases': []}```
#
# Scene 38: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene continues outside with a group of people involved in what seems like a tense or chaotic situation on the lawn. There is a sense of urgency and movement among those present.'}}, 'kind': 'audioVisual', 'startTimeMs': 66984, 'endTimeMs': 68110, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [67577], 'transcriptPhrases': []}```
#
# Scene 39: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A brief, chaotic scene unfolds with individuals appearing to struggle or engage in a physical altercation on the ground outside a house.'}}, 'kind': 'audioVisual', 'startTimeMs': 68110, 'endTimeMs': 68569, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [68355], 'transcriptPhrases': []}```
#
# Scene 40: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene is dimly lit, with a person holding a firearm standing outside a house. The atmosphere is tense, suggesting a moment of confrontation or defense.'}}, 'kind': 'audioVisual', 'startTimeMs': 68569, 'endTimeMs': 70696, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [69256, 69952], 'transcriptPhrases': []}```
#
# Scene 41: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A group of individuals are seen approaching or confronting another person. The scene is tense, with a sense of impending conflict or resolution in a suburban neighborhood at night.'}}, 'kind': 'audioVisual', 'startTimeMs': 70696, 'endTimeMs': 71655, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [71181], 'transcriptPhrases': []}```
#
# Scene 42: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A person is seen holding a gun in a defensive posture. The background indicates a residential area, possibly from a front porch, with dim lighting suggesting nighttime. The audio includes a stern command, "Get off my lawn."'}}, 'kind': 'audioVisual', 'startTimeMs': 71655, 'endTimeMs': 73323, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [72205, 72737], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 71880, 'endTimeMs': 73200, 'text': 'Get off my lawn.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 43: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A group of young men stand together in the street, facing the person with the gun. They appear to be in a confrontational stance, and one of them warns, "You better watch your back."'}}, 'kind': 'audioVisual', 'startTimeMs': 73323, 'endTimeMs': 74866, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [73843, 74375], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 73680, 'endTimeMs': 74840, 'text': 'You better watch your back.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 44: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The person with the gun remains in a defensive stance, still facing the group. The setting continues to be the residential porch area, with tension in the air.'}}, 'kind': 'audioVisual', 'startTimeMs': 74866, 'endTimeMs': 76243, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [75563], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 75920, 'endTimeMs': 76480, 'text': 'Thank you.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 45: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A different group of people, possibly neighbors, stand together on the lawn, watching the confrontation unfold. They appear concerned about the situation.'}}, 'kind': 'audioVisual', 'startTimeMs': 76243, 'endTimeMs': 76827, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [76546], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 75920, 'endTimeMs': 76480, 'text': 'Thank you.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 46: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene shifts to a close-up of a person who seems to be reflecting on the situation. The screen fades to black intermittently, suggesting a transition or a lapse of time. The audio reflects a conversation about neighborhood troubles and a lack of police response.'}}, 'kind': 'audioVisual', 'startTimeMs': 76827, 'endTimeMs': 80747, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [77611, 78389, 79167, 79945], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 78320, 'endTimeMs': 80080, 'text': 'I heard there was some trouble in the neighborhood.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 47: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Two people are on a porch in daylight, engaged in a conversation. One is sitting, possibly smoking, while the other stands, facing them. The conversation touches on past events in the neighborhood.'}}, 'kind': 'audioVisual', 'startTimeMs': 80747, 'endTimeMs': 82833, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [81461, 82157], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 80960, 'endTimeMs': 82560, 'text': "Why didn't you call the police?", 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 82800, 'endTimeMs': 86840, 'text': 'I prayed that they would show up, but nobody answered.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 48: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The screen goes dark, indicating another transition. The audio suggests a continuation of the previous conversation, possibly with a sense of introspection or realization.'}}, 'kind': 'audioVisual', 'startTimeMs': 82833, 'endTimeMs': 84918, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [83549, 84246], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 82800, 'endTimeMs': 86840, 'text': 'I prayed that they would show up, but nobody answered.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 49: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The seated person from earlier continues the conversation, their face expressing concern or contemplation. The setting remains on the porch, surrounded by a green, suburban landscape.'}}, 'kind': 'audioVisual', 'startTimeMs': 84918, 'endTimeMs': 88005, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [85679, 86457, 87235], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 82800, 'endTimeMs': 86840, 'text': 'I prayed that they would show up, but nobody answered.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 50: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The person seen earlier is now at their front door, holding a gun, suggesting readiness or precaution. The setting indicates they are about to step outside.'}}, 'kind': 'audioVisual', 'startTimeMs': 88005, 'endTimeMs': 88922, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [88464], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 88880, 'endTimeMs': 90960, 'text': 'Why are you bringing me all this garbage anyway?', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 51: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Two individuals are seen placing flowers and offerings on the porch steps. This action suggests a gesture of respect or remembrance, possibly in response to a significant event.'}}, 'kind': 'audioVisual', 'startTimeMs': 88922, 'endTimeMs': 90382, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [89652], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 88880, 'endTimeMs': 90960, 'text': 'Why are you bringing me all this garbage anyway?', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 52: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene fades to black, marking the end of this particular segment. The audio captures a moment of silence or contemplation, indicating a pause in the narrative.'}}, 'kind': 'audioVisual', 'startTimeMs': 90382, 'endTimeMs': 91091, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [90758], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 88880, 'endTimeMs': 90960, 'text': 'Why are you bringing me all this garbage anyway?', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 53: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A group of people stand together in front of a house, appearing to be in conversation. The scene takes place outside, with a porch and a person observing from a distance.'}}, 'kind': 'audioVisual', 'startTimeMs': 91091, 'endTimeMs': 91842, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [91454], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 91120, 'endTimeMs': 92200, 'text': 'Because you saved how?', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 54: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The screen goes dark momentarily, possibly transitioning between scenes.'}}, 'kind': 'audioVisual', 'startTimeMs': 91842, 'endTimeMs': 92259, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [92068], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 91120, 'endTimeMs': 92200, 'text': 'Because you saved how?', 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 92200, 'endTimeMs': 94080, 'text': "I didn't save anybody.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 55: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The person with the firearm continues to aim, maintaining a steady posture in the dimly lit surroundings.'}}, 'kind': 'audioVisual', 'startTimeMs': 92301, 'endTimeMs': 93135, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [92314, 92724], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 92200, 'endTimeMs': 94080, 'text': "I didn't save anybody.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 56: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A group of individuals is seen walking away on a sidewalk at night, possibly leaving a tense situation.'}}, 'kind': 'audioVisual', 'startTimeMs': 93135, 'endTimeMs': 94011, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [93584], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 92200, 'endTimeMs': 94080, 'text': "I didn't save anybody.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 57: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The screen transitions to black, suggesting a pause or shift in the narrative.'}}, 'kind': 'audioVisual', 'startTimeMs': 94011, 'endTimeMs': 94469, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [94239], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 92200, 'endTimeMs': 94080, 'text': "I didn't save anybody.", 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 94400, 'endTimeMs': 95680, 'text': "You're a hero to the neighborhood.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 58: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'An older individual stands in front of a house, engaging in conversation with others. The setting is outdoors, indicating a continuation of the previous interaction.'}}, 'kind': 'audioVisual', 'startTimeMs': 94469, 'endTimeMs': 94928, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [94730], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 94400, 'endTimeMs': 95680, 'text': "You're a hero to the neighborhood.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 59: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The group of people from earlier continues their dialogue outside the house, suggesting a neighborhood gathering or meeting.'}}, 'kind': 'audioVisual', 'startTimeMs': 94928, 'endTimeMs': 95679, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [95304], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 94400, 'endTimeMs': 95680, 'text': "You're a hero to the neighborhood.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 60: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The older individual walks away from the group towards the house, while the others remain standing together, possibly concluding their interaction.'}}, 'kind': 'audioVisual', 'startTimeMs': 95679, 'endTimeMs': 97723, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [96369, 97065], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 94400, 'endTimeMs': 95680, 'text': "You're a hero to the neighborhood.", 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 95920, 'endTimeMs': 96680, 'text': "I'm not a hero.", 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 96680, 'endTimeMs': 99120, 'text': "We're having BBQ.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 61: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The older individual is now seated on a porch, accompanied by a dog. This serene setting contrasts with the previous tense moments.'}}, 'kind': 'audioVisual', 'startTimeMs': 97723, 'endTimeMs': 98849, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [98294], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 96680, 'endTimeMs': 99120, 'text': "We're having BBQ.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 62: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A young woman is seen approaching the porch, possibly to engage in conversation with the seated individual.'}}, 'kind': 'audioVisual', 'startTimeMs': 98849, 'endTimeMs': 99600, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [99235], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 96680, 'endTimeMs': 99120, 'text': "We're having BBQ.", 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 99120, 'endTimeMs': 99880, 'text': 'You want to come over?', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 63: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The older individual, seated, appears to be listening or observing something, with a focused expression.'}}, 'kind': 'audioVisual', 'startTimeMs': 99600, 'endTimeMs': 100517, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [100055], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 99120, 'endTimeMs': 99880, 'text': 'You want to come over?', 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 99880, 'endTimeMs': 101280, 'text': "We've got beer, too.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 64: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The young woman stands in front of the porch, with an American flag visible in the background, suggesting a patriotic setting.'}}, 'kind': 'audioVisual', 'startTimeMs': 100517, 'endTimeMs': 101393, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [100956], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 99880, 'endTimeMs': 101280, 'text': "We've got beer, too.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 65: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The older individual begins to rise from the porch seat, indicating a possible change in position or readiness to engage.'}}, 'kind': 'audioVisual', 'startTimeMs': 101393, 'endTimeMs': 102311, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [101857], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 101520, 'endTimeMs': 103760, 'text': 'I might as well drink with stranger.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 66: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Another brief transition to black, potentially marking the end of a scene or conversation.'}}, 'kind': 'audioVisual', 'startTimeMs': 102311, 'endTimeMs': 102811, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [102553], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 101520, 'endTimeMs': 103760, 'text': 'I might as well drink with stranger.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 67: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Inside a house, the older individual holds a bottle, possibly preparing to join a social gathering or event.'}}, 'kind': 'audioVisual', 'startTimeMs': 102811, 'endTimeMs': 103312, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [103085], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 101520, 'endTimeMs': 103760, 'text': 'I might as well drink with stranger.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 68: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A group of people are gathered inside a house, seemingly enjoying a social event, possibly a party or communal meal.'}}, 'kind': 'audioVisual', 'startTimeMs': 103312, 'endTimeMs': 104730, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [104027], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 101520, 'endTimeMs': 103760, 'text': 'I might as well drink with stranger.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 69: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Several individuals exit a car in an alleyway, suggesting the beginning of a new scene or storyline.'}}, 'kind': 'audioVisual', 'startTimeMs': 104730, 'endTimeMs': 105731, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [105256], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 104960, 'endTimeMs': 106880, 'text': 'Those guys were here the other night.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 70: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The older individual appears in the alleyway, standing and observing the people exiting the car, indicating a potential confrontation or meeting.'}}, 'kind': 'audioVisual', 'startTimeMs': 105731, 'endTimeMs': 106898, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [106321], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 104960, 'endTimeMs': 106880, 'text': 'Those guys were here the other night.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 71: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'An intense conversation takes place in a dimly lit room. An older man with white hair appears to be engaged in a serious discussion with a younger person. The atmosphere seems tense, possibly hinting at a disagreement or confrontation.'}}, 'kind': 'audioVisual', 'startTimeMs': 106898, 'endTimeMs': 108734, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [107509, 108123], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 107800, 'endTimeMs': 108320, 'text': 'What about him?', 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 108640, 'endTimeMs': 109360, 'text': 'Just a gang.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 72: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Inside a tool-filled room, a young individual stands, possibly contemplating something important. The setting suggests a workshop or garage, with various tools visible in the background.'}}, 'kind': 'audioVisual', 'startTimeMs': 108734, 'endTimeMs': 109401, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [109065], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 108640, 'endTimeMs': 109360, 'text': 'Just a gang.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# ...
#
# Scene 76: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'An older man is shown in a position of advantage, looking downwards, possibly at someone on the ground, suggesting a victorious stance following a conflict.'}}, 'kind': 'audioVisual', 'startTimeMs': 111236, 'endTimeMs': 111903, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [111563], 'transcriptPhrases': []}```
#
# Scene 77: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The older man from the previous scene looks directly at the camera, indicating a moment of realization or contemplation.'}}, 'kind': 'audioVisual', 'startTimeMs': 111903, 'endTimeMs': 112863, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [112382], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 111960, 'endTimeMs': 112800, 'text': "And here's zeal.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 78: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A person lies on the grass, seemingly subdued or incapacitated, following the altercation.'}}, 'kind': 'audioVisual', 'startTimeMs': 112863, 'endTimeMs': 113614, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [113242], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 113120, 'endTimeMs': 116240, 'text': "You stay away, because if I have to come back here again, it's going to be ugly.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 79: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The older man remains in focus, appearing to reflect on the recent events or possibly addressing the person on the ground.'}}, 'kind': 'audioVisual', 'startTimeMs': 113614, 'endTimeMs': 115032, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [114348], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 113120, 'endTimeMs': 116240, 'text': "You stay away, because if I have to come back here again, it's going to be ugly.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 80: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The camera once again captures the individual lying on the grass, emphasizing their motionless state.'}}, 'kind': 'audioVisual', 'startTimeMs': 115032, 'endTimeMs': 116199, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [115618], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 113120, 'endTimeMs': 116240, 'text': "You stay away, because if I have to come back here again, it's going to be ugly.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 81: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': "A close-up view shows the person's hands on the grass, indicating a possible struggle or attempt to rise."}}, 'kind': 'audioVisual', 'startTimeMs': 116199, 'endTimeMs': 116700, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [116437], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 113120, 'endTimeMs': 116240, 'text': "You stay away, because if I have to come back here again, it's going to be ugly.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 82: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The screen fades to black briefly before transitioning to a nighttime scene where a car is parked along a dark street.'}}, 'kind': 'audioVisual', 'startTimeMs': 116700, 'endTimeMs': 119036, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [117461, 118239], 'transcriptPhrases': []}```
#
# Scene 83: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A sudden burst of light suggests gunfire from a passing vehicle, directed towards a house.'}}, 'kind': 'audioVisual', 'startTimeMs': 119036, 'endTimeMs': 119536, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [119304], 'transcriptPhrases': []}```
#
# Scene 84: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The camera focuses on the windows of a house being shot at, with visible bullet impacts and broken glass.'}}, 'kind': 'audioVisual', 'startTimeMs': 119536, 'endTimeMs': 120120, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [119836], 'transcriptPhrases': []}```
#
# Scene 85: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A brief blackout on the screen possibly marks a transition or dramatic pause after the shooting scene.'}}, 'kind': 'audioVisual', 'startTimeMs': 120120, 'endTimeMs': 120287, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [120205], 'transcriptPhrases': []}```
#
# Scene 86: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'An individual is seen hurriedly exiting a house, possibly in response to the gunfire or another urgent situation.'}}, 'kind': 'audioVisual', 'startTimeMs': 120287, 'endTimeMs': 121038, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [120655], 'transcriptPhrases': []}```
#
# Scene 87: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene transitions to a clear view of a car driving away in the night, suggesting an escape or pursuit. A close-up of a military medal adds a layer of personal significance or backstory to the scene.'}}, 'kind': 'audioVisual', 'startTimeMs': 121038, 'endTimeMs': 123081, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [121720, 122416], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 122720, 'endTimeMs': 123920, 'text': 'What was it like to kill a man?', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 88: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A person is seen in a dimly lit room, possibly in a basement or similar setting, with a serious expression, indicative of a tense or reflective moment.'}}, 'kind': 'audioVisual', 'startTimeMs': 123081, 'endTimeMs': 124041, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [123563], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 122720, 'endTimeMs': 123920, 'text': 'What was it like to kill a man?', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 89: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Another individual is standing under a dim light bulb, suggesting an introspective or emotionally charged conversation. The setting appears confined and somber.'}}, 'kind': 'audioVisual', 'startTimeMs': 124041, 'endTimeMs': 125709, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [124587, 125119], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 124400, 'endTimeMs': 125360, 'text': "You don't want to know.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 90: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The screen momentarily goes black, creating a pause or transition in the scene, potentially heightening suspense.'}}, 'kind': 'audioVisual', 'startTimeMs': 125709, 'endTimeMs': 126251, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [125980], 'transcriptPhrases': []}```
#
# Scene 91: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene shifts to a dark interior of a car, with minimal visibility, enhancing a mood of secrecy or impending action.'}}, 'kind': 'audioVisual', 'startTimeMs': 126251, 'endTimeMs': 127419, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [126840], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 127200, 'endTimeMs': 131840, 'text': "Tao and Sue are never going to find peace in this world as long as that gang's around.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 92: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'Two young individuals, possibly Tao and Sue, are standing outside with police lights flashing in the background, indicating a situation involving law enforcement.'}}, 'kind': 'audioVisual', 'startTimeMs': 127419, 'endTimeMs': 128545, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [127986], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 127200, 'endTimeMs': 131840, 'text': "Tao and Sue are never going to find peace in this world as long as that gang's around.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 93: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A man sits in a darkened room, partially illuminated, suggesting deep thought or contemplation about past or future actions.'}}, 'kind': 'audioVisual', 'startTimeMs': 128545, 'endTimeMs': 130380, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [129174, 129788], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 127200, 'endTimeMs': 131840, 'text': "Tao and Sue are never going to find peace in this world as long as that gang's around.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 94: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A car filled with individuals, one of whom has a bandana on his head, drives by, suggesting the presence of gang members or a tense situation involving this group.'}}, 'kind': 'audioVisual', 'startTimeMs': 130380, 'endTimeMs': 131548, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [130976], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 127200, 'endTimeMs': 131840, 'text': "Tao and Sue are never going to find peace in this world as long as that gang's around.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 95: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The scene transitions to a dimly lit room where a man appears to be listening intently or preparing to speak, with the atmosphere conveying tension.'}}, 'kind': 'audioVisual', 'startTimeMs': 131548, 'endTimeMs': 134551, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [132287, 133024, 133761], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 127200, 'endTimeMs': 131840, 'text': "Tao and Sue are never going to find peace in this world as long as that gang's around.", 'confidence': 1, 'words': [], 'locale': 'en-US'}, {'speaker': 'speaker', 'startTimeMs': 131840, 'endTimeMs': 133360, 'text': 'What are you going to do, Walt?', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 96: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A man stands on a porch in daylight, gazing outward, possibly contemplating a significant decision or observing a situation unfolding.'}}, 'kind': 'audioVisual', 'startTimeMs': 134551, 'endTimeMs': 135844, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [135195], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 134800, 'endTimeMs': 135840, 'text': 'Whatever it is.', 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 97: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'A car is driving down a street, suggesting movement or an ongoing pursuit, possibly linked to previous events involving a gang.'}}, 'kind': 'audioVisual', 'startTimeMs': 135844, 'endTimeMs': 137095, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [136464], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 136520, 'endTimeMs': 137760, 'text': "They won't have a chance.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 98: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The man on the porch extends his arm, possibly pointing or gesturing in response to something seen on the street.'}}, 'kind': 'audioVisual', 'startTimeMs': 137095, 'endTimeMs': 138305, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [137693], 'transcriptPhrases': [{'speaker': 'speaker', 'startTimeMs': 136520, 'endTimeMs': 137760, 'text': "They won't have a chance.", 'confidence': 1, 'words': [], 'locale': 'en-US'}]}```
#
# Scene 99: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': "The title 'GRAN TORINO' appears on the screen, indicating the film's title, accompanied by a dramatic pause or musical cue."}}, 'kind': 'audioVisual', 'startTimeMs': 138305, 'endTimeMs': 141933, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [139044, 139782, 140519, 141256], 'transcriptPhrases': []}```
#
# Scene 100: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The production credits begin to appear against a dark background, listing the production companies and key contributors to the film.'}}, 'kind': 'audioVisual', 'startTimeMs': 141933, 'endTimeMs': 142851, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [142403], 'transcriptPhrases': []}```
#
# Scene 101: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': "The segment displays the closing credits of a film, highlighting key contributors. It lists David Johannson and Nick Schenk for story, Nick Schenk for screenplay, Robert Lorenz and Bill Gerber for production, and Clint Eastwood for direction. The film's website and production company, Warner Bros., are also mentioned."}}, 'kind': 'audioVisual', 'startTimeMs': 142851, 'endTimeMs': 143894, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [143386], 'transcriptPhrases': []}```
#
# Scene 102: The following is a json string representing a video segment with scene description and transcript ```{'fields': {'segmentDescription': {'type': 'string', 'valueString': 'The screen transitions to black, marking the end of the closing credits. This indicates the conclusion of the video content.'}}, 'kind': 'audioVisual', 'startTimeMs': 143894, 'endTimeMs': 144895, 'width': 1280, 'height': 534, 'KeyFrameTimesMs': [144410], 'transcriptPhrases': []}```

# %% [markdown]
# ## Embed and index the chunks
# Add the scene description segments as documents to Azure Search.

# %%
start = time.time()

vector_store = load_into_index(segments)

elapsed = time.time() - start
print(f"Done in {time.strftime('%H:%M:%S.' + str(elapsed % 1)[2:5], time.gmtime(elapsed))}")
# Out:
# Done in 00:00:09.137

# %%
# Please wait a couple of seconds to get the results
index_status(AZURE_SEARCH_INDEX_NAME)
# Out:
# Azure AI Search Index: azure_cu_movieteaser
#
# {
#      "@odata.context": "https://azureaisearch-sr.search.windows.net/$metadata#indexes/$entity",
#      "@odata.etag": "\"0x8DD41F3835CFFD5\"",
#      "name": "azure_cu_movieteaser",
#      "defaultScoringProfile": null,
#      "fields": [
#           {
#                "name": "id",
#                "type": "Edm.String",
#                "searchable": false,
#                "filterable": true,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": true,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "content",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": false,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "content_vector",
#                "type": "Collection(Edm.Single)",
#                "searchable": true,
#                "filterable": false,
#                "retrievable": false,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           },
#           {
#                "name": "metadata",
#                "type": "Edm.String",
#                "searchable": true,
#                "filterable": false,
#                "retrievable": true,
#                "sortable": false,
#                "facetable": false,
#                "key": false,
#                "indexAnalyzer": null,
#                "searchAnalyzer": null,
#                "analyzer": null,
#                "normalizer": null,
#                "synonymMaps": []
#           }
#      ],
#      "scoringProfiles": [],
#      "corsOptions": null,
#      "suggesters": [],
#      "analyzers": [],
#      "normalizers": [],
#      "tokenizers": [],
#      "tokenFilters": [],
#      "charFilters": [],
#      "encryptionKey": null,
#      "similarity": {
#           "@odata.type": "#Microsoft.Azure.Search.BM25Similarity",
#           "k1": null,
#           "b": null
#      },
#      "semantic": null
# }

# %%
document_count, storage_size = get_index_stats(AZURE_SEARCH_INDEX_NAME)
# Out:
# Azure Cognitive Search index status for: azure_cu_movieteaser
#
# {
#   "@odata.context": "https://azureaisearch-sr.search.windows.net/$metadata#Microsoft.Azure.Search.V2021_04_30_Preview.IndexStatistics",
#   "documentCount": 102,
#   "storageSize": 2135075
# }

# %%
print("Number of documents in the Azure AI Search index =", f"{document_count:,}")
print("Size of the index =", round(storage_size / (1024 * 1024), 2), "MB")
# Out:
# Number of documents in the Azure AI Search index = 102
# Size of the index = 2.04 MB

# %% [markdown]
# ## Retrieve relevant content
# #### Execute a pure vector similarity search

# %%
query = "ford"

# Perform a similarity search
docs = vector_store.similarity_search(
    query=query,
    k=3,
    search_type="similarity",
)

display_results(docs)
# Out:
# Results 1:
#
# Scene description: A close-up shot shows someone meticulously polishing a Gran Torino Sport car. The focus is on the care and attention given to the vehicle, indicating its importance or sentimental value to the person cleaning it.
# Kind: audioVisual
# StartTimeMs: 24358
# EndTimeMs: 26443
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [25065, 25761]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 26240', '"endTimeMs": 27600', '"text": "Dad', 'you worked hard your whole life."', '"confidence": 1', '"words": [']
#
# Results 2:
#
# Scene description: A close-up shot of a person cleaning a "Gran Torino Sport" car with a cloth. This action highlights attention to detail and care for the vehicle, suggesting a sense of pride and ownership.
# Kind: audioVisual
# StartTimeMs: 24358
# EndTimeMs: 26443
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [25065, 25761]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 26240', '"endTimeMs": 27600', '"text": "Dad', 'you worked hard your whole life."', '"confidence": 1', '"words": [']
#
# Results 3:
#
# Scene description: The older man is now standing outside his white pickup truck, facing a group of young individuals on the street, suggesting a confrontation.
# Kind: audioVisual
# StartTimeMs: 11386
# EndTimeMs: 13347
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [12041, 12696]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 10760', '"endTimeMs": 14760', '"text": "Never knows how you come across somebody once in a while you shouldn"t have messed with."', '"confidence": 1', '"words": [']

# %%
generate_subclip(video_file, 25065, 25761)
Video("sample.mp4", width=512)
# Out:
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isommp42', 'creation_time': '2018-11-15T20:06:06.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1280, 534], 'bitrate': 847, 'fps': 23.976023976023978, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 44100, 'bitrate': 127, 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 144.92000000000002, 'bitrate': 978, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 534], 'video_bitrate': 847, 'video_fps': 23.976023976023978, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 44100, 'audio_bitrate': 127, 'video_duration': 144.92000000000002, 'video_n_frames': 3474}
# /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i documents/movie.mp4 -loglevel error -f image2pipe -vf scale=1280:534 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isommp42', 'creation_time': '2018-11-15T20:06:06.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1280, 534], 'bitrate': 847, 'fps': 23.976023976023978, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 44100, 'bitrate': 127, 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 144.92000000000002, 'bitrate': 978, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 534], 'video_bitrate': 847, 'video_fps': 23.976023976023978, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 44100, 'audio_bitrate': 127, 'video_duration': 144.92000000000002, 'video_n_frames': 3474}
# /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -ss 23.000000 -i documents/movie.mp4 -ss 1.000000 -loglevel error -f image2pipe -vf scale=1280:534 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# MoviePy - Building video sample.mp4.
# MoviePy - Writing audio in sampleTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video sample.mp4
# MoviePy - Done !
# MoviePy - video ready sample.mp4
# <video src="sample.mp4" controls  width="512" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# #### Execute hybrid search. Vector and nonvector text fields are queried in parallel, results are merged, and top matches of the unified result set are returned.

# %%
# Perform a hybrid search using the search_type parameter
docs = vector_store.hybrid_search(query=query, k=3)

display_results(docs)
# Out:
# Results 1:
#
# Scene description: A close-up shot shows someone meticulously polishing a Gran Torino Sport car. The focus is on the care and attention given to the vehicle, indicating its importance or sentimental value to the person cleaning it.
# Kind: audioVisual
# StartTimeMs: 24358
# EndTimeMs: 26443
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [25065, 25761]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 26240', '"endTimeMs": 27600', '"text": "Dad', 'you worked hard your whole life."', '"confidence": 1', '"words": [']
#
# Results 2:
#
# Scene description: A close-up shot of a person cleaning a "Gran Torino Sport" car with a cloth. This action highlights attention to detail and care for the vehicle, suggesting a sense of pride and ownership.
# Kind: audioVisual
# StartTimeMs: 24358
# EndTimeMs: 26443
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [25065, 25761]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 26240', '"endTimeMs": 27600', '"text": "Dad', 'you worked hard your whole life."', '"confidence": 1', '"words": [']
#
# Results 3:
#
# Scene description: The older man is now standing outside his white pickup truck, facing a group of young individuals on the street, suggesting a confrontation.
# Kind: audioVisual
# StartTimeMs: 11386
# EndTimeMs: 13347
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [12041, 12696]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 10760', '"endTimeMs": 14760', '"text": "Never knows how you come across somebody once in a while you shouldn"t have messed with."', '"confidence": 1', '"words": [']

# %% [markdown]
# ## Others queries

# %%
query = "priest"

# Perform a hybrid search using the search_type parameter
docs = vector_store.hybrid_search(query=query, k=3)
display_results(docs)
# Out:
# Results 1:
#
# Scene description: Inside the church, several people are seated in the pews, dressed formally. The setting suggests a solemn or formal occasion, possibly a service or ceremony.
# Kind: audioVisual
# StartTimeMs: 49007
# EndTimeMs: 50676
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [49556, 50089]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 49120', '"endTimeMs": 52880', '"text": "Dorothy mentioned specifically that it was her desire for you to go to confession."', '"confidence": 1', '"words": [']
#
# Results 2:
#
# Scene description: Inside the church, a group of people is seated in the pews. The atmosphere is somber, suggesting a service or ceremony is taking place. The attendees are dressed in formal attire, indicating the seriousness of the occasion.
# Kind: audioVisual
# StartTimeMs: 49007
# EndTimeMs: 50676
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [49556, 50089]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 49120', '"endTimeMs": 52880', '"text": "Dorothy mentioned specifically that it was her desire for you to go to confession."', '"confidence": 1', '"words": [']
#
# Results 3:
#
# Scene description: The interior gathering continues, with a focus on two individuals in conversation. The setting appears to be a social gathering, possibly following the church service, with people interacting in a warmly lit room.
# Kind: audioVisual
# StartTimeMs: 51552
# EndTimeMs: 52928
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [51563, 52259]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 49120', '"endTimeMs": 52880', '"text": "Dorothy mentioned specifically that it was her desire for you to go to confession."', '"confidence": 1', '"words": [']

# %%
generate_subclip(video_file, 49556, 50089)
Video("sample.mp4", width=512)
# Out:
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isommp42', 'creation_time': '2018-11-15T20:06:06.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1280, 534], 'bitrate': 847, 'fps': 23.976023976023978, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 44100, 'bitrate': 127, 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 144.92000000000002, 'bitrate': 978, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 534], 'video_bitrate': 847, 'video_fps': 23.976023976023978, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 44100, 'audio_bitrate': 127, 'video_duration': 144.92000000000002, 'video_n_frames': 3474}
# /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i documents/movie.mp4 -loglevel error -f image2pipe -vf scale=1280:534 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isommp42', 'creation_time': '2018-11-15T20:06:06.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1280, 534], 'bitrate': 847, 'fps': 23.976023976023978, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 44100, 'bitrate': 127, 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 144.92000000000002, 'bitrate': 978, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 534], 'video_bitrate': 847, 'video_fps': 23.976023976023978, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 44100, 'audio_bitrate': 127, 'video_duration': 144.92000000000002, 'video_n_frames': 3474}
# /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -ss 47.000000 -i documents/movie.mp4 -ss 1.000000 -loglevel error -f image2pipe -vf scale=1280:534 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# MoviePy - Building video sample.mp4.
# MoviePy - Writing audio in sampleTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video sample.mp4
# MoviePy - Done !
# MoviePy - video ready sample.mp4
# <video src="sample.mp4" controls  width="512" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
query = "birthday cake"

docs = vector_store.hybrid_search(query=query, k=3)
display_results(docs)
# Out:
# Results 1:
#
# Scene description: The camera focuses on a beautifully decorated birthday cake with the words "Happy Birthday Dad" written in blue frosting. This sets a celebratory and familial tone.
# Kind: audioVisual
# StartTimeMs: 26443
# EndTimeMs: 27819
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [27154]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 26240', '"endTimeMs": 27600', '"text": "Dad', 'you worked hard your whole life."', '"confidence": 1', '"words": [']
#
# Results 2:
#
# Scene description: A birthday cake with the message "Happy Birthday Dad" is displayed on a table, surrounded by plates and utensils. This signifies a celebration, likely a family gathering, honoring a father figure.
# Kind: audioVisual
# StartTimeMs: 26443
# EndTimeMs: 27819
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [27154]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 26240', '"endTimeMs": 27600', '"text": "Dad', 'you worked hard your whole life."', '"confidence": 1', '"words": [']
#
# Results 3:
#
# Scene description: In a domestic setting, individuals are gathered, possibly for a family occasion, judging by the previous context of the birthday cake. The atmosphere suggests a familial gathering, perhaps a birthday celebration.
# Kind: audioVisual
# StartTimeMs: 27819
# EndTimeMs: 29154
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [28505]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 27920', '"endTimeMs": 30560', '"text": "Maybe it"s time you started thinking about taking it easier."', '"confidence": 1', '"words": [']

# %%
generate_subclip(video_file, 26443, 27819)
Video("sample.mp4", width=512)
# Out:
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isommp42', 'creation_time': '2018-11-15T20:06:06.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1280, 534], 'bitrate': 847, 'fps': 23.976023976023978, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 44100, 'bitrate': 127, 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 144.92000000000002, 'bitrate': 978, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 534], 'video_bitrate': 847, 'video_fps': 23.976023976023978, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 44100, 'audio_bitrate': 127, 'video_duration': 144.92000000000002, 'video_n_frames': 3474}
# /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i documents/movie.mp4 -loglevel error -f image2pipe -vf scale=1280:534 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isommp42', 'creation_time': '2018-11-15T20:06:06.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1280, 534], 'bitrate': 847, 'fps': 23.976023976023978, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 44100, 'bitrate': 127, 'metadata': {'Metadata': '', 'creation_time': '2018-11-15T20:06:06.000000Z', 'handler_name': 'ISO Media file produced by Google Inc. Created on: 11/15/2018.', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 144.92000000000002, 'bitrate': 978, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 534], 'video_bitrate': 847, 'video_fps': 23.976023976023978, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 44100, 'audio_bitrate': 127, 'video_duration': 144.92000000000002, 'video_n_frames': 3474}
# /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -ss 24.000000 -i documents/movie.mp4 -ss 1.000000 -loglevel error -f image2pipe -vf scale=1280:534 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# MoviePy - Building video sample.mp4.
# MoviePy - Writing audio in sampleTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video sample.mp4
# MoviePy - Done !
# MoviePy - video ready sample.mp4
# <video src="sample.mp4" controls  width="512" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
query = "Clint Eastwood"

docs = vector_store.hybrid_search(query=query, k=3)
display_results(docs)
# Out:
# Results 1:
#
# Scene description: The segment showcases a series of credits introducing the director, Clint Eastwood. The text gradually becomes clearer, emphasizing the director"s name. This segment sets the stage for the film, highlighting the prominent role of Clint Eastwood in its creation.
# Kind: audioVisual
# StartTimeMs: 19394
# EndTimeMs: 23315
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [20191, 20969, 21747, 22526]
# TranscriptPhrases: []
#
# Results 2:
#
# Scene description: The segment showcases a series of credits introducing the director, Clint Eastwood. The text gradually appears on a black screen, creating a dramatic and anticipatory atmosphere.
# Kind: audioVisual
# StartTimeMs: 19394
# EndTimeMs: 23315
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [20191, 20969, 21747, 22526]
# TranscriptPhrases: []
#
# Results 3:
#
# Scene description: A close-up shot of a person cleaning a "Gran Torino Sport" car with a cloth. This action highlights attention to detail and care for the vehicle, suggesting a sense of pride and ownership.
# Kind: audioVisual
# StartTimeMs: 24358
# EndTimeMs: 26443
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [25065, 25761]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 26240', '"endTimeMs": 27600', '"text": "Dad', 'you worked hard your whole life."', '"confidence": 1', '"words": [']

# %%
query = "American flag"

docs = vector_store.hybrid_search(query=query, k=3)
display_results(docs)
# Out:
# Results 1:
#
# Scene description: The young woman stands in front of the porch, with an American flag visible in the background, suggesting a patriotic setting.
# Kind: audioVisual
# StartTimeMs: 100517
# EndTimeMs: 101393
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [100956]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 99880', '"endTimeMs": 101280', '"text": "We"ve got beer', 'too."', '"confidence": 1', '"words": [']
#
# Results 2:
#
# Scene description: The exterior of a house is shown, illuminated by a porch light. An American flag is displayed prominently, and a car is parked in front of the house, suggesting a typical suburban setting. The scene conveys a sense of nighttime tranquility.
# Kind: audioVisual
# StartTimeMs: 61228
# EndTimeMs: 62521
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [61884]
# TranscriptPhrases: []
#
# Results 3:
#
# Scene description: An elderly man is standing outside a house, with an American flag visible in the background. He appears to be observing something or someone, possibly the couple leaving the house.
# Kind: audioVisual
# StartTimeMs: 40541
# EndTimeMs: 41416
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [40997]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 40480', '"endTimeMs": 42720', '"text": "These Chinese after moving this they rode for."', '"confidence": 1', '"words": [']

# %%
query = "Gun"

docs = vector_store.hybrid_search(query=query, k=3)
display_results(docs)
# Out:
# Results 1:
#
# Scene description: The person with the gun remains in a defensive stance, still facing the group. The setting continues to be the residential porch area, with tension in the air.
# Kind: audioVisual
# StartTimeMs: 74866
# EndTimeMs: 76243
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [75563]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 75920', '"endTimeMs": 76480', '"text": "Thank you."', '"confidence": 1', '"words": [']
#
# Results 2:
#
# Scene description: A person is seen holding a gun in a defensive posture. The background indicates a residential area, possibly from a front porch, with dim lighting suggesting nighttime. The audio includes a stern command, "Get off my lawn."
# Kind: audioVisual
# StartTimeMs: 71655
# EndTimeMs: 73323
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [72205, 72737]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 71880', '"endTimeMs": 73200', '"text": "Get off my lawn."', '"confidence": 1', '"words": [']
#
# Results 3:
#
# Scene description: A person is seen holding a shotgun in a defensive posture. The scene is tense, taking place outside a house at night, indicating a confrontation.
# Kind: audioVisual
# StartTimeMs: 71655
# EndTimeMs: 73323
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [72205, 72737]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 71880', '"endTimeMs": 73200', '"text": "Get off my lawn."', '"confidence": 1', '"words": [']

# %%
query = "White pickup"

docs = vector_store.hybrid_search(query=query, k=3)
display_results(docs)
# Out:
# Results 1:
#
# Scene description: The older man is now standing outside his white pickup truck, facing a group of young individuals on the street, suggesting a confrontation.
# Kind: audioVisual
# StartTimeMs: 11386
# EndTimeMs: 13347
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [12041, 12696]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 10760', '"endTimeMs": 14760', '"text": "Never knows how you come across somebody once in a while you shouldn"t have messed with."', '"confidence": 1', '"words": [']
#
# Results 2:
#
# Scene description: The scene transitions to a street corner with a stop sign. A white pickup truck passes by, while a group of people stand near a brick building, indicating an urban setting.
# Kind: audioVisual
# StartTimeMs: 3253
# EndTimeMs: 4963
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [3809, 4382]
# TranscriptPhrases: []
#
# Results 3:
#
# Scene description: A scene is shown depicting a quiet urban street corner. A white pickup truck drives past a stop sign, and a group of individuals can be seen standing near a brick building. The street is lined with houses and appears to be a typical suburban area.
# Kind: audioVisual
# StartTimeMs: 3253
# EndTimeMs: 4963
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [3809, 4382]
# TranscriptPhrases: []

# %%
query = "emergency vehicle"

docs = vector_store.hybrid_search(query=query, k=3)
display_results(docs)
# Out:
# Results 1:
#
# Scene description: A nighttime street view shows a vehicle rapidly driving away, possibly the shooter"s getaway. The scene then briefly displays a military medal, suggesting a connection to a character"s past or achievements.
# Kind: audioVisual
# StartTimeMs: 121038
# EndTimeMs: 123081
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [121720, 122416]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 122720', '"endTimeMs": 123920', '"text": "What was it like to kill a man?"', '"confidence": 1', '"words": [']
#
# Results 2:
#
# Scene description: Two individuals stand outside at night with a police car in the background, indicating a serious or possibly dangerous situation.
# Kind: audioVisual
# StartTimeMs: 127419
# EndTimeMs: 128545
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [127986]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 127200', '"endTimeMs": 131840', '"text": "Tao and Sue are never going to find peace in this world as long as that gang"s around."', '"confidence": 1', '"words": [']
#
# Results 3:
#
# Scene description: A sudden burst of light suggests gunfire from a passing vehicle, directed towards a house.
# Kind: audioVisual
# StartTimeMs: 119036
# EndTimeMs: 119536
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [119304]
# TranscriptPhrases: []

# %%
query = "a person who is cleaning a car"

docs = vector_store.hybrid_search(query=query, k=3)
display_results(docs)
# Out:
# Results 1:
#
# Scene description: A close-up shot of a person cleaning a "Gran Torino Sport" car with a cloth. This action highlights attention to detail and care for the vehicle, suggesting a sense of pride and ownership.
# Kind: audioVisual
# StartTimeMs: 24358
# EndTimeMs: 26443
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [25065, 25761]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 26240', '"endTimeMs": 27600', '"text": "Dad', 'you worked hard your whole life."', '"confidence": 1', '"words": [']
#
# Results 2:
#
# Scene description: A close-up shot shows someone meticulously polishing a Gran Torino Sport car. The focus is on the care and attention given to the vehicle, indicating its importance or sentimental value to the person cleaning it.
# Kind: audioVisual
# StartTimeMs: 24358
# EndTimeMs: 26443
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [25065, 25761]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 26240', '"endTimeMs": 27600', '"text": "Dad', 'you worked hard your whole life."', '"confidence": 1', '"words": [']
#
# Results 3:
#
# Scene description: A car filled with individuals, one of whom has a bandana on his head, drives by, suggesting the presence of gang members or a tense situation involving this group.
# Kind: audioVisual
# StartTimeMs: 130380
# EndTimeMs: 131548
# Width: 1280
# Height: 534
# KeyFrameTimesMs: [130976]
# TranscriptPhrases: ['{"speaker": "speaker"', '"startTimeMs": 127200', '"endTimeMs": 131840', '"text": "Tao and Sue are never going to find peace in this world as long as that gang"s around."', '"confidence": 1', '"words": [']

# %% [markdown]
# ## Video Q&A
# We can utilize OpenAI GPT completion models + Azure Search to conversationally search for and chat about the results. (If you are using GitHub Codespaces, there will be an input prompt near the top of the screen)

# %%
# Setup rag chain
prompt_video = """You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
Question: {question} 
Context: {context} 
Answer:"""

# %%
print(prompt_video)
# Out:
# You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
# Question: {question}
# Context: {context}
# Answer:

# %%
def setup_rag_chain(vector_store):
    """
    Set up a Retrieval-Augmented Generation (RAG) chain using Azure OpenAI and Azure Search.

    This function configures a RAG chain by creating a retriever from the provided vector store,
    formatting documents, and setting up a language model with a prompt template.

    Args:
        vector_store (AzureSearch): An AzureSearch object used to retrieve documents based on similarity.

    Returns:
        dict: A dictionary representing the RAG chain, which includes the context retriever, prompt,
              language model, and output parser.
    """
    # Retriever
    retriever = vector_store.as_retriever(search_type="similarity", k=3)
    # Prompt
    prompt = ChatPromptTemplate.from_template(prompt_video)
    # LLM
    llm = AzureChatOpenAI(
        azure_endpoint=AZURE_OPENAI_ENDPOINT,
        openai_api_version=AZURE_OPENAI_CHAT_API_VERSION,
        azure_deployment=AZURE_OPENAI_CHAT_DEPLOYMENT_NAME,
        azure_ad_token_provider=token_provider,
        temperature=0.7,
    )

    def format_docs(docs):
        return "\n\n".join(doc.page_content for doc in docs)

    # RAG chain
    rag_chain = ({
        "context": retriever | format_docs,
        "question": RunnablePassthrough()
    }
                 | prompt
                 | llm
                 | StrOutputParser())

    return rag_chain

# %%
# Enter a query. Enter an empty query to stop
rag_chain = setup_rag_chain(vector_store)

while True:
    query = input("Ask the video: ")
    if query == "":
        break
    conversational_search(rag_chain, query)
# Out:
# Ask the video:  hello
# Hello! How can I assist you today?
# Ask the video:  what is this video?
# The video appears to depict a series of tense and confrontational scenes involving an older man and a group of young individuals in a residential neighborhood. The older man is shown in a victorious stance and later appears focused on a woman or something nearby outside a house. Additionally, the group of young individuals is involved in a tense situation, warning someone off-camera to "watch your back."
# Ask the video:  what are the people names?
# The people mentioned in the context are Tao and Sue.
# Ask the video:  who is the director?
# The director is Clint Eastwood.
# Ask the video:  Do we have some cars?
# Yes, the context describes scenes with cars, including a Gran Torino Sport car being polished and a car filled with individuals driving by.
# Ask the video:  Do we have a ford car?
# Yes, the context mentions a "Gran Torino Sport" car, which is a model manufactured by Ford.
# Ask the video:

# %% [markdown]
# ## Post Processing

# %%
# Delete the analyzer if it is no longer needed
client.delete_analyzer(ANALYZER_ID)
# Out:
# <Response [204]>
